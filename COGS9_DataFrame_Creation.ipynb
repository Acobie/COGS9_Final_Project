# %% [markdown]
# # Creating DataFrames for Each State
#
# This file creates DataFrames for each state with 2020 Presidential Election Data and Total COVID-19 Cases as of mid-December.

# %%
# Imports - these are provided for you. Do not import any other packages.
import pandas as pd
import requests
import bs4
import time
from bs4 import BeautifulSoup

# %% [markdown]
# ### Creating initial DataFrame with election data

# %%
# List of states to iterate through
state_list = ['Alabama','Alaska','Arizona','Arkansas','California','Colorado','Connecticut','Delaware','Florida','Georgia','Hawaii','Idaho','Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana','Maine','Maryland','Massachusetts','Michigan','Minnesota','Mississippi','Missouri','Montana','Nebraska','Nevada','New-Hampshire','New-Jersey','New-Mexico','New-York','North-Carolina','North-Dakota','Ohio','Oklahoma','Oregon','Pennsylvania','Rhode-Island','South-Carolina','South-Dakota','Tennessee','Texas','Utah','Vermont','Virginia','Washington','West Virginia','Wisconsin','Wyoming']

# Dictionary to store all DataFrames for each state
df_dictionary = {}

# Iterate through state list
for state in state_list:
    
    # Skip the special case
    if(state == 'Alaska'):
        continue
    
    # Create lists to hold county names, democrat votes and percent, republican votes and percent
    county_list, dem_per, dem_votes, rep_per, rep_votes = [], [], [], [], []
    
    # Lower case string states
    state.lower
    
    # Build URL to scrape data about election
    election_page = 'https://abcnews.go.com/Elections/' + state.lower() + '-county-presidential-election-results-2020'
    page = requests.get(election_page).text
    soup = BeautifulSoup(page, 'html.parser')
    divs = soup.findAll('div', class_='CountyResults_result')
    
    # Temporary 1 second sleep timer to not overwhelm website with requests
    time.sleep(1)
    
    # Iterate through html and find data for each county
    for div in divs:
        
        # Save county name
        name = div.find('h2').text
        
        # Special case for named county in Louisiana
        if(state == 'Louisiana' and name == 'La Salle Parish'):
            name = 'LaSalle Parish';
        county_list.append(name)
    
        # Democrats info
        democrats = div.find('tr', class_='ElectionsTable__Row ResultsTable--counting ResultsTable__row--democrats')
        dems_vote = int(democrats.find('td', class_='ElectionsTable__Cell ResultsTable__votes').text.replace(',',''))
        dems_per = int(democrats.find('td', class_='ElectionsTable__Cell ResultsTable__percent').text.replace('%',''))
    
        # Append info scraped to lists
        dem_votes.append(dems_vote)
        dem_per.append(dems_per)

        # Republicans info
        republicans = div.find('tr', class_='ElectionsTable__Row ResultsTable--counting ResultsTable__row--republicans')
        reps_vote = int(republicans.find('td', class_='ElectionsTable__Cell ResultsTable__votes').text.replace(',',''))
        reps_per = int(republicans.find('td', class_='ElectionsTable__Cell ResultsTable__percent').text.replace('%',''))
    
        # Append info scraped to lists
        rep_votes.append(reps_vote)
        rep_per.append(reps_per)
    
    # Create DataFrames from lists for current state
    df = pd.DataFrame()
    df['County'] = county_list
    df['Democrat Votes'] = dem_votes
    df['Democrat %'] = dem_per
    df['Republican Votes'] = rep_votes
    df['Republican %'] = rep_per
    df.set_index('County', inplace=True)
    
    # Save to dictionary with Key as state and Value as DataFrame
    df_dictionary[state] = df
    
    print('Saving dataframe for ' + state)
# Out:
# Saving dataframe for Alabama
# Saving dataframe for Arizona
# Saving dataframe for Arkansas
# Saving dataframe for California
# Saving dataframe for Colorado
# Saving dataframe for Connecticut
# Saving dataframe for Delaware
# Saving dataframe for Florida
# Saving dataframe for Georgia
# Saving dataframe for Hawaii
# Saving dataframe for Idaho
# Saving dataframe for Illinois
# Saving dataframe for Indiana
# Saving dataframe for Iowa
# Saving dataframe for Kansas
# Saving dataframe for Kentucky
# Saving dataframe for Louisiana
# Saving dataframe for Maine
# Saving dataframe for Maryland
# Saving dataframe for Massachusetts
# Saving dataframe for Michigan
# Saving dataframe for Minnesota
# Saving dataframe for Mississippi
# Saving dataframe for Missouri
# Saving dataframe for Montana
# Saving dataframe for Nebraska
# Saving dataframe for Nevada
# Saving dataframe for New-Hampshire
# Saving dataframe for New-Jersey
# Saving dataframe for New-Mexico
# Saving dataframe for New-York
# Saving dataframe for North-Carolina
# Saving dataframe for North-Dakota
# Saving dataframe for Ohio
# Saving dataframe for Oklahoma
# Saving dataframe for Oregon
# Saving dataframe for Pennsylvania
# Saving dataframe for Rhode-Island
# Saving dataframe for South-Carolina
# Saving dataframe for South-Dakota
# Saving dataframe for Tennessee
# Saving dataframe for Texas
# Saving dataframe for Utah
# Saving dataframe for Vermont
# Saving dataframe for Virginia
# Saving dataframe for Washington
# Saving dataframe for West Virginia
# Saving dataframe for Wisconsin
# Saving dataframe for Wyoming

# %% [markdown]
# ### Appending population data to existing DataFrames

# %%
# List of state abbreviations to iterate through
state_abrv = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI','ID','IL','IN','IA','KS','KY','LA','ME','MD','MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','RI','SC','SD','TN','TX','UT','VT','VA','WA','WV','WI','WY']

# Iterate through state list
for x in range(50):
    
    # Skip the special case
    if(state_abrv[x] == 'AK'):
        continue
    
    # Temporary 1 second sleep timer to not overwhelm website with requests
    time.sleep(1)
    
    # Build URL to scrape data about population
    population_page = 'https://worldpopulationreview.com/us-counties/states/' + state_abrv[x].lower()
    page = requests.get(population_page).text
    soup = BeautifulSoup(page, 'html.parser')
    table_pop = soup.findAll('tr')

    # Create lists to hold county names and population
    county_list, pop = [], []
    
    # Skip heading in population table
    heading = True
    
    # Iterate through html and find info for each county
    for row in table_pop:
        # Skip heading in table
        if heading:
            heading = False
            continue
    
        # Find each column in the row
        row = row.findAll('td')
    
        # Save county name
        county_name = row[0].find('a').text
        
        # Special case for accented county in New Mexico
        if state_abrv[x] == 'NM' and county_name == 'Do̱a Ana County':
            county_name = 'Dona Ana County'
        county_list.append(county_name)
    
        # Save population info
        pops = int(row[1].find(text=True).replace(',',''))
        pop.append(pops)

    # Create DataFrame for population for each county
    pops_df = pd.DataFrame()
    pops_df['County'] = county_list
    pops_df['Population'] = pop
    pops_df.set_index('County', inplace=True)
    
    # Combine population data to existing DataFrames with voter information
    df_dictionary[state_list[x]] = pd.concat([df_dictionary[state_list[x]],pops_df], axis=1, sort=True)
    print('Adding population to ' + state_list[x])
# Out:
# Adding population to Alabama
# Adding population to Arizona
# Adding population to Arkansas
# Adding population to California
# Adding population to Colorado
# Adding population to Connecticut
# Adding population to Delaware
# Adding population to Florida
# Adding population to Georgia
# Adding population to Hawaii
# Adding population to Idaho
# Adding population to Illinois
# Adding population to Indiana
# Adding population to Iowa
# Adding population to Kansas
# Adding population to Kentucky
# Adding population to Louisiana
# Adding population to Maine
# Adding population to Maryland
# Adding population to Massachusetts
# Adding population to Michigan
# Adding population to Minnesota
# Adding population to Mississippi
# Adding population to Missouri
# Adding population to Montana
# Adding population to Nebraska
# Adding population to Nevada
# Adding population to New-Hampshire
# Adding population to New-Jersey
# Adding population to New-Mexico
# Adding population to New-York
# Adding population to North-Carolina
# Adding population to North-Dakota
# Adding population to Ohio
# Adding population to Oklahoma
# Adding population to Oregon
# Adding population to Pennsylvania
# Adding population to Rhode-Island
# Adding population to South-Carolina
# Adding population to South-Dakota
# Adding population to Tennessee
# Adding population to Texas
# Adding population to Utah
# Adding population to Vermont
# Adding population to Virginia
# Adding population to Washington
# Adding population to West Virginia
# Adding population to Wisconsin
# Adding population to Wyoming

# %% [markdown]
# ### Appending COVID-19 data to existing DataFrames

# %%
# Iterate through list of states used earlier for election data
for state in state_list:
    
     # Temporary 1 second sleep timer to not overwhelm website with requests
    time.sleep(1)
    
    # Skip the special case
    if(state == 'Alaska'):
        continue
    
    # Build URL to scrape data about total COVID-19 cases 
    covid_page = 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/' + state.lower()
    page = requests.get(covid_page).text
    soup = BeautifulSoup(page, 'html.parser')
    covid_table = soup.find('tbody').findAll('tr')
    
    # Create list to save number of total cases in each county
    total_cases = []

    # Iterate through html and find info for each county
    for row in covid_table:
        
        # Save cases info
        cases = int(row.find('td').text.replace(',',''))
        total_cases.append(cases)
    
    # Add new column 'Total COVID-19 Cases' to existing DataFrames for each state
    df_dictionary[state]['Total COVID-19 Cases'] = total_cases
    print('Adding COVID-19 data to ' + state)
# Out:
# Adding COVID-19 data to Alabama
# Adding COVID-19 data to Arizona
# Adding COVID-19 data to Arkansas
# Adding COVID-19 data to California
# Adding COVID-19 data to Colorado
# Adding COVID-19 data to Connecticut
# Adding COVID-19 data to Delaware
# Adding COVID-19 data to Florida
# Adding COVID-19 data to Georgia
# Adding COVID-19 data to Hawaii
# Adding COVID-19 data to Idaho
# Adding COVID-19 data to Illinois
# Adding COVID-19 data to Indiana
# Adding COVID-19 data to Iowa
# Adding COVID-19 data to Kansas
# Adding COVID-19 data to Kentucky
# Adding COVID-19 data to Louisiana
# Adding COVID-19 data to Maine
# Adding COVID-19 data to Maryland
# Adding COVID-19 data to Massachusetts
# Adding COVID-19 data to Michigan
# Adding COVID-19 data to Minnesota
# Adding COVID-19 data to Mississippi
# Adding COVID-19 data to Missouri
# Adding COVID-19 data to Montana
# Adding COVID-19 data to Nebraska
# Adding COVID-19 data to Nevada
# Adding COVID-19 data to New-Hampshire
# Adding COVID-19 data to New-Jersey
# Adding COVID-19 data to New-Mexico
# Adding COVID-19 data to New-York
# Adding COVID-19 data to North-Carolina
# Adding COVID-19 data to North-Dakota
# Adding COVID-19 data to Ohio
# Adding COVID-19 data to Oklahoma
# Adding COVID-19 data to Oregon
# Adding COVID-19 data to Pennsylvania
# Adding COVID-19 data to Rhode-Island
# Adding COVID-19 data to South-Carolina
# Adding COVID-19 data to South-Dakota
# Adding COVID-19 data to Tennessee
# Adding COVID-19 data to Texas
# Adding COVID-19 data to Utah
# Adding COVID-19 data to Vermont
# Adding COVID-19 data to Virginia
# Adding COVID-19 data to Washington
# Adding COVID-19 data to West Virginia
# Adding COVID-19 data to Wisconsin
# Adding COVID-19 data to Wyoming

# %% [markdown]
# # Examples of DataFrames

# %%
# Sanity Check. Example of what each DataFrame for each state looks like
df_dictionary['New-Jersey']
# Out:
#                    Democrat Votes  Democrat %  Republican Votes  Republican %  \
# Atlantic County             73808          53             64438            46
# Bergen County              285967          58            204417            41
# Burlington County          154595          59            103345            39
# Camden County              175065          66             86207            33
# Cape May County             23941          41             33158            57
# Cumberland County           32742          52             28952            46
# Essex County               266820          77             75475            22
# Gloucester County           86702          50             83340            48
# Hudson County              181452          72             65698            26
# Hunterdon County            39457          47             43153            51
# Mercer County              122532          69             51641            29
# Middlesex County           226250          60            143467            38
# Monmouth County            181291          48            191808            51
# Morris County              153881          51            141134            47
# Ocean County               119456          35            217740            64
# Passaic County             129097          58             92009            41
# Salem County                14479          43             18827            55
# Somerset County            111173          60             71996            39
# Sussex County               34481          39             51698            59
# Union County               170245          67             80002            32
# Warren County               24901          41             34769            57
#
#                    Population  Total COVID-19 Cases
# Atlantic County        263351                  9654
# Bergen County          931588                 40483
# Burlington County      445953                 16874
# Camden County          506589                 23633
# Cape May County         91632                  1970
# Cumberland County      148419                  6218
# Essex County           799380                 41089
# Gloucester County      291747                 11472
# Hudson County          672851                 37187
# Hunterdon County       123935                  3040
# Mercer County          366672                 16134
# Middlesex County       823952                 36739
# Monmouth County        617131                 25288
# Morris County          490620                 16692
# Ocean County           612894                 26145
# Passaic County         500469                 35368
# Salem County            62024                  2163
# Somerset County        327687                 10671
# Sussex County          140175                  3349
# Union County           556280                 32383
# Warren County          105006                  3079

# %%
df_dictionary['California']
# Out:
#                         Democrat Votes  Democrat %  Republican Votes  \
# Alameda County                  617659          80            136309
# Alpine County                      476          64               244
# Amador County                     8153          36             13585
# Butte County                     50426          49             48730
# Calaveras County                 10046          37             16518
# Colusa County                     3234          41              4554
# Contra Costa County             416386          72            152877
# Del Norte County                  4677          41              6461
# El Dorado County                 51621          44             61838
# Fresno County                   193025          53            164464
# Glenn County                      3995          35              7063
# Humboldt County                  44768          65             21770
# Imperial County                  34678          61             20847
# Inyo County                       4634          49              4620
# Kern County                     133366          44            164484
# Kings County                     18699          43             24072
# Lake County                      14941          52             13123
# Lassen County                     2799          23              8970
# Los Angeles County             3028885          71           1145530
# Madera County                    23168          43             29378
# Marin County                    128288          82             24612
# Mariposa County                   4088          40              5950
# Mendocino County                 28782          66             13267
# Merced County                    48991          54             39397
# Modoc County                      1150          27              3109
# Mono County                       4013          60              2513
# Monterey County                 113953          70             46299
# Napa County                      49817          69             20676
# Nevada County                    36359          56             26779
# Orange County                   814009          54            676498
# Placer County                   106869          46            122488
# Plumas County                     4561          41              6445
# Riverside County                527945          53            448702
# Sacramento County               440808          61            259405
# San Benito County                17628          61             10590
# San Bernardino County           455859          54            366257
# San Diego County                964650          60            600094
# San Francisco County            378156          85             56417
# San Joaquin County              161137          56            121098
# San Luis Obispo County           88310          55             67436
# San Mateo County                291410          78             75563
# Santa Barbara County            129963          65             65736
# Santa Clara County              617967          73            214612
# Santa Cruz County               114246          79             26937
# Shasta County                    30000          32             60789
# Sierra County                      730          38              1142
# Siskiyou County                   9593          41             13290
# Solano County                   131639          64             69306
# Sonoma County                   199938          75             61825
# Stanislaus County               105841          49            104145
# Sutter County                    17367          41             24375
# Tehama County                     8911          31             19141
# Trinity County                    2851          46              3188
# Tulare County                    66105          45             77579
# Tuolumne County                  11978          39             17689
# Ventura County                  251388          60            162207
# Yolo County                      67598          70             27292
# Yuba County                      11230          38             17676
#
#                         Republican %  Population  Total COVID-19 Cases
# Alameda County                    18     1675900                 36185
# Alpine County                     33        1169                     5
# Amador County                     61       40099                   706
# Butte County                      48      208033                  4912
# Calaveras County                  61       46112                   642
# Colusa County                     57       21676                   921
# Contra Costa County               26     1156530                 29760
# Del Norte County                  56       27884                   536
# El Dorado County                  53      194940                  3754
# Fresno County                     45     1006250                 43071
# Glenn County                      63       28819                  1136
# Humboldt County                   32      134872                  1231
# Imperial County                   37      180907                 18289
# Inyo County                       49       18132                   388
# Kern County                       54      906646                 50624
# Kings County                      55      154498                 13356
# Lake County                       46       64455                  1215
# Lassen County                     75       30528                  3127
# Los Angeles County                27    10004300                525486
# Madera County                     55      157772                  7612
# Marin County                      16      257990                  8489
# Mariposa County                   58       17001                   174
# Mendocino County                  31       86097                  1953
# Merced County                     44      281209                 14483
# Modoc County                      72        8882                   240
# Mono County                       37       14485                   440
# Monterey County                   28      434172                 17635
# Napa County                       29      136699                  4013
# Nevada County                     41      100002                  1962
# Orange County                     45     3175410                102514
# Placer County                     52      404328                  8879
# Plumas County                     57       18873                    94
# Riverside County                  45     2495300                112950
# Sacramento County                 36     1565370                 47473
# San Benito County                 37       64149                  2401
# San Bernardino County             44     2193420                126738
# San Diego County                  38     3342800                104956
# San Francisco County              13      882402                 18326
# San Joaquin County                42      771805                 31720
# San Luis Obispo County            42      282868                  7452
# San Mateo County                  20      764465                 17724
# Santa Barbara County              33      447218                 13198
# Santa Clara County                25     1923370                 48015
# Santa Cruz County                 19      272585                  5642
# Shasta County                     65      180451                  6853
# Sierra County                     59        3013                    27
# Siskiyou County                   57       43528                   914
# Solano County                     34      449561                 12733
# Sonoma County                     23      490029                 14475
# Stanislaus County                 48      553194                 26361
# Sutter County                     57       97594                  4657
# Tehama County                     67       66150                  2357
# Trinity County                    51       12003                   225
# Tulare County                     53      467801                 25042
# Tuolumne County                   58       54569                  1653
# Ventura County                    38      843870                 24276
# Yolo County                       28      220882                  6117
# Yuba County                       59       79779                  2820

# %%
# Check special case for Louisiana
pd.set_option('display.max_rows', 200)
display(df_dictionary['Louisiana'])
# Out:
#                              Democrat Votes  Democrat %  Republican Votes  \
# Acadia Parish                          5443          19             22596
# Allen Parish                           2108          22              7574
# Ascension Parish                      20399          33             40687
# Assumption Parish                      3833          34              7271
# Avoyelles Parish                       4979          29             12028
# Beauregard Parish                      2542          16             13575
# Bienville Parish                       3067          44              3891
# Bossier Parish                        15662          29             38074
# Caddo Parish                          55110          53             48021
# Calcasieu Parish                      25982          31             55066
# Caldwell Parish                         745          16              3976
# Cameron Parish                          324           8              3671
# Catahoula Parish                       1269          26              3541
# Claiborne Parish                       2731          42              3770
# Concordia Parish                       3177          36              5550
# De Soto Parish                         5457          37              9112
# East Baton Rouge Parish              115577          56             88420
# East Carroll Parish                    1900          63              1080
# East Feliciana Parish                  4280          41              6064
# Evangeline Parish                      4158          27             11053
# Franklin Parish                        2658          27              6970
# Grant Parish                           1157          12              8117
# Iberia Parish                         11027          34             21251
# Iberville Parish                       8514          51              7893
# Jackson Parish                         2143          28              5394
# Jefferson Davis Parish                 3208          22             11423
# Jefferson Parish                      84477          44            105949
# LaSalle Parish                          638           9              6378
# Lafayette Parish                      39685          35             72519
# Lafourche Parish                       8672          19             36024
# Lincoln Parish                         7559          39             11311
# Livingston Parish                      9249          14             54877
# Madison Parish                         2654          57              1930
# Morehouse Parish                       4946          43              6510
# Natchitoches Parish                    6896          42              9358
# Orleans Parish                       147854          83             26664
# Ouachita Parish                       25913          38             42255
# Plaquemines Parish                     3414          31              7412
# Pointe Coupee Parish                   4683          38              7503
# Rapides Parish                        19475          33             38347
# Red River Parish                       1644          40              2413
# Richland Parish                        3225          32              6607
# Sabine Parish                          1731          16              8776
# St. Bernard Parish                     6151          35             11179
# St. Charles Parish                     9800          34             18233
# St. Helena Parish                      3346          54              2714
# St. James Parish                       6510          52              5954
# St. John the Baptist Parish           13582          63              7538
# St. Landry Parish                     17372          42             23171
# St. Martin Parish                      8439          31             18203
# St. Mary Parish                        8055          35             14811
# St. Tammany Parish                    37746          27             99666
# Tangipahoa Parish                     18887          33             37806
# Tensas Parish                          1329          52              1197
# Terrebonne Parish                     11198          24             34339
# Union Parish                           2654          24              8407
# Vermilion Parish                       5009          18             21930
# Vernon Parish                          2898          17             14107
# Washington Parish                      5970          31             13307
# Webster Parish                         6172          34             11830
# West Baton Rouge Parish                6200          44              7684
# West Carroll Parish                     710          14              4317
# West Feliciana Parish                  2298          37              3863
# Winn Parish                            1543          25              4619
#
#                              Republican %  Population  Total COVID-19 Cases
# Acadia Parish                          80       61876                  4522
# Allen Parish                           77       25687                  2234
# Ascension Parish                       65      128350                  6734
# Assumption Parish                      65       21503                  1155
# Avoyelles Parish                       70       39886                  2352
# Beauregard Parish                      83       37625                  1582
# Bienville Parish                       55       13139                  1002
# Bossier Parish                         70      127056                  7384
# Caddo Parish                           46      237575                 15245
# Calcasieu Parish                       67      203695                 11822
# Caldwell Parish                        84        9872                   763
# Cameron Parish                         91        6933                   332
# Catahoula Parish                       73        9382                   720
# Claiborne Parish                       57       15445                   848
# Concordia Parish                       63       18932                  1216
# De Soto Parish                         62       27500                  1488
# East Baton Rouge Parish                43      438060                 22468
# East Carroll Parish                    36        6728                   892
# East Feliciana Parish                  58       18984                  2271
# Evangeline Parish                      72       33294                  2274
# Franklin Parish                        72       19866                  1856
# Grant Parish                           86       22342                  1183
# Iberia Parish                          65       68755                  4186
# Iberville Parish                       47       32329                  2348
# Jackson Parish                         71       15576                  1263
# Jefferson Davis Parish                 77       31199                  1999
# Jefferson Parish                       55      431102                 26686
# LaSalle Parish                         90       14883                  1045
# Lafayette Parish                       63      245667                 14200
# Lafourche Parish                       79       97247                  5388
# Lincoln Parish                         59       46372                  2945
# Livingston Parish                      84      142184                  7279
# Madison Parish                         41       10706                  1161
# Morehouse Parish                       56       24424                  1736
# Natchitoches Parish                    57       37700                  2447
# Orleans Parish                         15      389284                 17949
# Ouachita Parish                        61      151987                 11649
# Plaquemines Parish                     67       23009                  1436
# Pointe Coupee Parish                   61       21581                  1642
# Rapides Parish                         65      128970                  7101
# Red River Parish                       58        8358                   613
# Richland Parish                        67       20021                  1544
# Sabine Parish                          83       23867                  1794
# St. Bernard Parish                     63       47708                  2036
# St. Charles Parish                     64       53425                  2996
# St. Helena Parish                      44       10077                   597
# St. James Parish                       47       21041                  1135
# St. John the Baptist Parish            35       42555                  2231
# St. Landry Parish                      56       81466                  5747
# St. Martin Parish                      67       53300                  3182
# St. Mary Parish                        64       48855                  2630
# St. Tammany Parish                     71      262803                 12257
# Tangipahoa Parish                      66      135679                  7836
# Tensas Parish                          47        4198                   240
# Terrebonne Parish                      74      109759                  5097
# Union Parish                           75       21973                  1573
# Vermilion Parish                       80       59136                  2958
# Vernon Parish                          82       46757                  1696
# Washington Parish                      68       45800                  2583
# Webster Parish                         65       37888                  2328
# West Baton Rouge Parish                55       26530                  1569
# West Carroll Parish                    86       10683                   779
# West Feliciana Parish                  62       15644                   851
# Winn Parish                            74       13670                  1122

# %%
# Check special case for New Mexico
df_dictionary['New-Mexico']
# Out:
#                    Democrat Votes  Democrat %  Republican Votes  Republican %  \
# Bernalillo County          193757          61            116135            37
# Catron County                 595          26              1698            73
# Chaves County                6381          28             15656            70
# Cibola County                4745          53              3975            45
# Colfax County                2611          43              3271            54
# Curry County                 4307          29             10444            69
# De Baca County                231          26               656            73
# Dona Ana County             47957          58             32802            40
# Eddy County                  5424          23             17454            75
# Grant County                 7590          53              6553            45
# Guadalupe County             1234          56               917            42
# Harding County                179          35               319            63
# Hidalgo County                823          42              1120            57
# Lea County                   4061          19             16531            79
# Lincoln County               3194          31              6942            67
# Los Alamos County            7554          61              4278            35
# Luna County                  3563          44              4408            54
# McKinley County             18029          68              7801            30
# Mora County                  1745          65               903            34
# Otero County                 8485          36             14521            62
# Quay County                  1170          30              2634            68
# Rio Arriba County           10990          66              5408            33
# Roosevelt County             1802          27              4634            70
# San Juan County             18083          35             32874            63
# San Miguel County            7888          68              3421            30
# Sandoval County             40588          53             34174            45
# Santa Fe County             62530          76             18329            22
# Sierra County                2265          38              3542            60
# Socorro County               3722          52              3255            46
# Taos County                 13121          76              3715            22
# Torrance County              2344          32              4772            66
# Union County                  383          21              1388            78
# Valencia County             14263          44             17364            54
#
#                    Population  Total COVID-19 Cases
# Bernalillo County      680208                 34149
# Catron County            3500                    51
# Chaves County           64676                  5814
# Cibola County           26584                  1905
# Colfax County           11811                   396
# Curry County            48570                  3626
# De Baca County           1717                    70
# Dona Ana County        219112                 15384
# Eddy County             59191                  3611
# Grant County            26693                   639
# Guadalupe County         4266                   207
# Harding County            600                     7
# Hidalgo County           4165                   208
# Lea County              72597                  5508
# Lincoln County          19626                   933
# Los Alamos County       19750                   210
# Luna County             23541                  2163
# McKinley County         70823                  8399
# Mora County              4555                    66
# Otero County            68321                  1863
# Quay County              8264                   310
# Rio Arriba County       38819                  1759
# Roosevelt County        18241                  1182
# San Juan County        122417                  7923
# San Miguel County       27074                   595
# Sandoval County        148400                  6644
# Santa Fe County        150955                  6345
# Sierra County           10633                   456
# Socorro County          16570                   777
# Taos County             32747                   994
# Torrance County         15410                   408
# Union County             4010                   167
# Valencia County         77071                  4036
