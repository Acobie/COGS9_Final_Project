# %% [markdown]
# # Creating DataFrames for Each State
#
# This file creates DataFrames for each state with 2020 Presidential Election Data and Total COVID-19 Cases as of mid-December.

# %%
# Imports - these are provided for you. Do not import any other packages.
import pandas as pd
import requests
import bs4
import time
from bs4 import BeautifulSoup

# %% [markdown]
# ### Creating initial DataFrame with election data
#
# Data for 2020 Presidential Election was scraped from https://abcnews.go.com/Elections/california-county-presidential-election-results-2020

# %%
# List of states to iterate through
state_list = ['Alabama','Alaska','Arizona','Arkansas','California','Colorado','Connecticut','Delaware','Florida','Georgia','Hawaii','Idaho','Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana','Maine','Maryland','Massachusetts','Michigan','Minnesota','Mississippi','Missouri','Montana','Nebraska','Nevada','New-Hampshire','New-Jersey','New-Mexico','New-York','North-Carolina','North-Dakota','Ohio','Oklahoma','Oregon','Pennsylvania','Rhode-Island','South-Carolina','South-Dakota','Tennessee','Texas','Utah','Vermont','Virginia','Washington','West-Virginia','Wisconsin','Wyoming']

# Dictionary to store all DataFrames for each state
df_dictionary = {}

# Iterate through state list
for state in state_list:
    
    # Skip the special case
    if(state == 'Alaska'):
        continue
    
    # Create lists to hold county names, democrat votes and percent, republican votes and percent
    county_list, dem_per, dem_votes, rep_per, rep_votes = [], [], [], [], []
    
    # Build URL to scrape data about election
    election_page = 'https://abcnews.go.com/Elections/' + state.lower() + '-county-presidential-election-results-2020'
    page = requests.get(election_page).text
    soup = BeautifulSoup(page, 'html.parser')
    divs = soup.findAll('div', class_='CountyResults_result')
    
    # Temporary 1 second sleep timer to not overwhelm website with requests
    time.sleep(1)
    
    # Iterate through html and find data for each county
    for div in divs:
        
        # Save county name
        name = div.find('h2').text
        
        # Special case for named county in Louisiana
        if(state == 'Louisiana' and name == 'La Salle Parish'):
            name = 'LaSalle Parish';
        county_list.append(name)
    
        # Democrats info
        democrats = div.find('tr', class_='ElectionsTable__Row ResultsTable--counting ResultsTable__row--democrats')
        dems_vote = int(democrats.find('td', class_='ElectionsTable__Cell ResultsTable__votes').text.replace(',',''))
        dems_per = int(democrats.find('td', class_='ElectionsTable__Cell ResultsTable__percent').text.replace('%',''))
    
        # Append info scraped to lists
        dem_votes.append(dems_vote)
        dem_per.append(dems_per)

        # Republicans info
        republicans = div.find('tr', class_='ElectionsTable__Row ResultsTable--counting ResultsTable__row--republicans')
        reps_vote = int(republicans.find('td', class_='ElectionsTable__Cell ResultsTable__votes').text.replace(',',''))
        reps_per = int(republicans.find('td', class_='ElectionsTable__Cell ResultsTable__percent').text.replace('%',''))
    
        # Append info scraped to lists
        rep_votes.append(reps_vote)
        rep_per.append(reps_per)
    
    # Create DataFrames from lists for current state
    df = pd.DataFrame()
    df['County'] = county_list
    df['County Name'] = county_list
    df['Democrat Votes'] = dem_votes
    df['Democrat %'] = dem_per
    df['Republican Votes'] = rep_votes
    df['Republican %'] = rep_per
    df.set_index('County', inplace=True)
    
    # Save to dictionary with Key as state and Value as DataFrame
    df_dictionary[state] = df
    
    # print('Saving dataframe for ' + state)

# %% [markdown]
# ### Appending population data to existing DataFrames
#
# Data for Population was scrape from
# https://worldpopulationreview.com/us-counties/states/ca

# %%
# List of state abbreviations to iterate through
state_abrv = ['AL','AK','AZ','AR','CA','CO','CT','DE','FL','GA','HI','ID','IL','IN','IA','KS','KY','LA','ME','MD','MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','OH','OK','OR','PA','RI','SC','SD','TN','TX','UT','VT','VA','WA','WV','WI','WY']

# Iterate through state list
for x in range(50):
    
    # Skip the special case
    if(state_abrv[x] == 'AK'):
        continue
    
    # Temporary 1 second sleep timer to not overwhelm website with requests
    time.sleep(1)
    
    # Build URL to scrape data about population
    population_page = 'https://worldpopulationreview.com/us-counties/states/' + state_abrv[x].lower()
    page = requests.get(population_page).text
    soup = BeautifulSoup(page, 'html.parser')
    table_pop = soup.findAll('tr')

    # Create lists to hold county names and population
    county_list, pop = [], []
    
    # Skip heading in population table
    heading = True
    
    # Iterate through html and find info for each county
    for row in table_pop:
        
        # Skip heading in table
        if heading:
            heading = False
            continue
    
        # Find each column in the row
        row = row.findAll('td')
    
        # Save county name
        county_name = row[0].find('a').text
        
        # Special case for Hawaii
        if state_abrv[x] == 'HI' and county_name == 'Kalawao County':
            continue
        
        # Special case for accented county in New Mexico
        elif state_abrv[x] == 'NM' and county_name == 'Do̱a Ana County':
            county_name = 'Dona Ana County'
        county_list.append(county_name)
    
        # Save population info
        pops = int(row[1].find(text=True).replace(',',''))
        pop.append(pops)

    # Create DataFrame for population for each county
    pops_df = pd.DataFrame()
    pops_df['County'] = county_list
    pops_df['Population'] = pop
    pops_df.set_index('County', inplace=True)
    
    # Combine population data to existing DataFrames with voter information
    df_dictionary[state_list[x]] = pd.concat([df_dictionary[state_list[x]],pops_df], axis=1, sort=True)
    # print('Adding population to ' + state_list[x])

# %% [markdown]
# ### Appending population density data to existing DataFrames
#
# They say most of a Data Scientist's time is spent cleaning the data...
# <br>
# <sup>My sanity was tested during this portion.</sup>
# <br>
# Data for Population Density was scraped from http://www.usa.com/rank/california-state--population-density--county-rank.htm

# %%
# Iterate through state_list and state_abrv
for x in range(50):
   
    # Skip the special case
    if(state_abrv[x] == 'AK'):
        continue

    # Temporary 1 second sleep timer to not overwhelm website with requests
    time.sleep(1)
    
    # Build URL to scrape data about population density
    pop_density_url = 'http://www.usa.com/rank/' + state_list[x].lower() + '-state--population-density--county-rank.htm'
    page = requests.get(pop_density_url).text
    soup = BeautifulSoup(page, 'html.parser')
    
    # Grab the table from the website
    pop_dens_table = soup.findAll('table')
    rows = pop_dens_table[1].findAll('tr')

    # Create lists to hold county names and population
    county_list, pop_density = [], []

    # Skip heading in population table
    heading = True

    # Iterate through html and find info for each county
    for row in rows:
    
        # Skip heading in table
        if heading:
            heading = False
            continue
    
        # Find each column in the row
        content = row.findAll('td')
        
        # Save county name
        county = content[2].find('a').text.replace(', ' + state_abrv[x], ' County').replace('Saint', 'St.')
        
        # Special cases for many states...
        if state_list[x] == 'Alabama':
            if county == 'De Kalb County':
                county = 'DeKalb County'
        
        elif state_list[x] == 'Florida':
            if county == 'De Soto County':
                county = 'DeSoto County'

        elif state_list[x] == 'Georgia':
            if county == 'Dekalb County':
                county = 'DeKalb County'
            elif county == 'Mcduffie County':
                county = 'McDuffie County'
            elif county == 'Mcintosh County':
                county = 'McIntosh County'

        elif state_list[x] == 'Illinois':
            if county == 'Dekalb County':
                county = 'DeKalb County'
            elif county == 'Dewitt County':
                county = 'De Witt County'
            elif county == 'Dupage County':
                county = 'DuPage County'
            elif county == 'La Salle County':
                county = 'LaSalle County'
            elif county == 'Mcdonough County':
                county = 'McDonough County'
            elif county == 'Mchenry County':
                county = 'McHenry County'
            elif county == 'Mclean County':
                county = 'McLean County'
        
        elif state_list[x] == 'Indiana':
            if county == 'De Kalb County':
                county = 'DeKalb County'
            elif county == 'La Porte County':
                county = 'LaPorte County'
            elif county == 'Lagrange County':
                county = 'LaGrange County'
            elif county == 'St Joseph County':
                county = 'St. Joseph County'

        elif state_list[x] == 'Iowa':
            if county == 'Obrien County':
                county = 'O\'Brien County'
        
        elif state_list[x] == 'Kansas':
            if county == 'Mcpherson County':
                county = 'McPherson County'

        elif state_list[x] == 'Kentucky':
            if county == 'Mccracken County':
                county = 'McCracken County'
            elif county == 'Mccreary County':
                county = 'McCreary County'
            elif county == 'Mclean County':
                county = 'McLean County'
        
        elif state_list[x] == 'Louisiana':
            county = county.replace('County', 'Parish')
            if county == 'La Salle Parish':
                county = 'LaSalle Parish'
            elif county == 'St John The Baptist Parish':
                county = 'St. John the Baptist Parish'

        elif state_list[x] == 'Maryland':
            if county == 'Baltimore City County':
                county = 'Baltimore city'
            elif county == 'Prince Georges County':
                county = 'Prince George\'s County'
            elif county == 'Queen Annes County':
                county = 'Queen Anne\'s County'
            elif county == 'St. Marys County':
                county = 'St. Mary\'s County'
        
        elif state_list[x] == 'Minnesota':
            if county == 'Lac Qui Parle County':
                county = 'Lac qui Parle County'
            elif county == 'Lake Of The Woods County':
                county = 'Lake of the Woods County'
            elif county == 'Mcleod County':
                county = 'McLeod County'
        
        elif state_list[x] == 'Mississippi':
            if county == 'Desoto County':
                county = 'DeSoto County'
        
        elif state_list[x] == 'Missouri':
            if county == 'Dekalb County':
                county = 'DeKalb County'
            elif county == 'Mcdonald County':
                county = 'McDonald County'
            elif county == 'St. Louis City County':
                county = 'St. Louis city'
            elif county == 'St.e Genevieve County':
                county = 'Ste. Genevieve County'
        
        elif state_list[x] == 'Montana':
            if county == 'Lewis And Clark County':
                county = 'Lewis and Clark County'
            elif county == 'Mccone County':
                county = 'McCone County'
        
        elif state_list[x] == 'Nebraska':
            if county == 'Mcpherson County':
                county = 'McPherson County'
                
        elif state_list[x] == 'Nevada':
            if county == 'Carson City County':
                county = 'Carson City'
                
        elif state_list[x] == 'New-Mexico':
            if county == 'Mckinley County':
                county = 'McKinley County'
        
        elif state_list[x] == 'North-Carolina':
            if county == 'Mcdowell County':
                county = 'McDowell County'
        
        elif state_list[x] == 'North-Dakota':
            if county == 'Lamoure County':
                county = 'LaMoure County'
            elif county == 'Mchenry County':
                county = 'McHenry County'
            elif county == 'Mcintosh County':
                county = 'McIntosh County'
            elif county == 'Mckenzie County':
                county = 'McKenzie County'
            elif county == 'Mclean County':
                county = 'McLean County'
                
        elif state_list[x] == 'Oklahoma':
            if county == 'Mcclain County':
                county = 'McClain County'
            elif county == 'Mccurtain County':
                county = 'McCurtain County'
            elif county == 'Mcintosh County':
                county = 'McIntosh County'
                
        elif state_list[x] == 'Pennsylvania':
            if county == 'Mckean County':
                county = 'McKean County'
            
        elif state_list[x] == 'South-Carolina':
            if county == 'Mccormick County':
                county = 'McCormick County'
                
        elif state_list[x] == 'South-Dakota':
            if county == 'Mccook County':
                county = 'McCook County'
            elif county == 'Mcpherson County':
                county = 'McPherson County'
            elif county == 'Shannon County':
                county = 'Oglala Lakota County'
        
        elif state_list[x] == 'Tennessee':
            if county == 'Dekalb County':
                county = 'DeKalb County'
            elif county == 'Mcminn County':
                county = 'McMinn County'
            elif county == 'Mcnairy County':
                county = 'McNairy County'
                
        elif state_list[x] == 'Texas':
            if county == 'De Witt County':
                county = 'DeWitt County'
            elif county == 'Mcculloch County':
                county = 'McCulloch County'
            elif county == 'Mclennan County':
                county = 'McLennan County'
            elif county == 'Mcmullen County':
                county = 'McMullen County'

        elif state_list[x] == 'Virginia':
            county = county.replace('City County', 'city')
            if county == 'Bristol County':
                county = 'Bristol city'
            elif county == 'Charles city':
                county = 'Charles City County'
            elif county == 'Isle Of Wight County':
                county = 'Isle of Wight County'
            elif county == 'James city':
                county = 'James City County'
            elif county == 'King And Queen County':
                county = 'King and Queen County'
            elif county == 'Radford County':
                county = 'Radford city'
            elif county == 'Salem County':
                county = 'Salem city'
        
        elif state_list[x] == 'West-Virginia':
            if county == 'Mcdowell County':
                county = 'McDowell County'
                
        elif state_list[x] == 'Wisconsin':
            if county == 'Fond Du Lac County':
                county = 'Fond du Lac County'
        
        # Save density info
        density = float(content[1].text.replace(',', '').replace('/sq mi', ''))
    
        # Append saved info to lists
        county_list.append(county)
        pop_density.append(density)
    
    # Special case where density data was missing
    if state_list[x] == 'Virginia':
        county_list.append('Emporia city')
        pop_density.append(float(776.3))
    
    # Create DataFrame for population density for each county
    density_df = pd.DataFrame()
    density_df['County'] = county_list
    density_df['Population Density (per sq mi)'] = pop_density
    density_df.set_index('County', inplace=True)
    
    # Combine population density data to existing DataFrames with voter information
    df_dictionary[state_list[x]] = pd.concat([df_dictionary[state_list[x]], density_df], axis=1, sort=True)
    # print('Adding population density data to '+ state_list[x])

# %% [markdown]
# ### Appending COVID-19 data to existing DataFrames
#
# Data for COVID-19 was scraped from https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/california

# %%
# Iterate through list of states used earlier for election data
for state in state_list:
    
     # Temporary 1 second sleep timer to not overwhelm website with requests
    time.sleep(1)
    
    # Skip the special case
    if(state == 'Alaska'):
        continue
    
    # Build URL to scrape data about total COVID-19 cases 
    covid_page = 'https://usafacts.org/visualizations/coronavirus-covid-19-spread-map/state/' + state.lower()
    page = requests.get(covid_page).text
    soup = BeautifulSoup(page, 'html.parser')
    covid_table = soup.find('tbody').findAll('tr')
    
    # Create list to save number of total cases in each county
    total_cases = []

    # Iterate through html and find info for each county
    for row in covid_table:
        
        # Save cases info
        cases = int(row.find('td').text.replace(',',''))
        total_cases.append(cases)
    
    # Special case for Hawaii
    if state == 'Hawaii':
        del total_cases[2]
    
    # Add new column 'Total COVID-19 Cases' to existing DataFrames for each state
    df_dictionary[state]['Total COVID-19 Cases'] = total_cases
    # print('Adding COVID-19 data to ' + state)

# %% [markdown]
# # Examples of DataFrames
#
# Sanity checks

# %%
df_dictionary['New-Jersey']
# Out:
#                          County Name  Democrat Votes  Democrat %  \
# Atlantic County      Atlantic County           73808          53
# Bergen County          Bergen County          285967          58
# Burlington County  Burlington County          154595          59
# Camden County          Camden County          175065          66
# Cape May County      Cape May County           23941          41
# Cumberland County  Cumberland County           32742          52
# Essex County            Essex County          266820          77
# Gloucester County  Gloucester County           86702          50
# Hudson County          Hudson County          181452          72
# Hunterdon County    Hunterdon County           39457          47
# Mercer County          Mercer County          122532          69
# Middlesex County    Middlesex County          226250          60
# Monmouth County      Monmouth County          181291          48
# Morris County          Morris County          153881          51
# Ocean County            Ocean County          119456          35
# Passaic County        Passaic County          129097          58
# Salem County            Salem County           14479          43
# Somerset County      Somerset County          111173          60
# Sussex County          Sussex County           34481          39
# Union County            Union County          170245          67
# Warren County          Warren County           24901          41
#
#                    Republican Votes  Republican %  Population  \
# Atlantic County               64438            46      263351
# Bergen County                204417            41      931588
# Burlington County            103345            39      445953
# Camden County                 86207            33      506589
# Cape May County               33158            57       91632
# Cumberland County             28952            46      148419
# Essex County                  75475            22      799380
# Gloucester County             83340            48      291747
# Hudson County                 65698            26      672851
# Hunterdon County              43153            51      123935
# Mercer County                 51641            29      366672
# Middlesex County             143467            38      823952
# Monmouth County              191808            51      617131
# Morris County                141134            47      490620
# Ocean County                 217740            64      612894
# Passaic County                92009            41      500469
# Salem County                  18827            55       62024
# Somerset County               71996            39      327687
# Sussex County                 51698            59      140175
# Union County                  80002            32      556280
# Warren County                 34769            57      105006
#
#                    Population Density (per sq mi)  Total COVID-19 Cases
# Atlantic County                             409.8                 10174
# Bergen County                              3731.5                 42008
# Burlington County                           549.1                 17812
# Camden County                              2255.4                 24872
# Cape May County                             155.2                  2070
# Cumberland County                           232.3                  6550
# Essex County                               6091.3                 42666
# Gloucester County                           859.2                 12052
# Hudson County                             10509.5                 38675
# Hunterdon County                            289.7                  3185
# Mercer County                              1614.4                 16897
# Middlesex County                           2552.6                 38857
# Monmouth County                             946.5                 26824
# Morris County                              1032.1                 17547
# Ocean County                                635.1                 27522
# Passaic County                             2564.1                 36690
# Salem County                                175.9                  2303
# Somerset County                            1078.2                 11222
# Sussex County                               274.2                  3555
# Union County                               5173.0                 33588
# Warren County                               296.6                  3289

# %%
df_dictionary['California']
# Out:
#                                    County Name  Democrat Votes  Democrat %  \
# Alameda County                  Alameda County          617659          80
# Alpine County                    Alpine County             476          64
# Amador County                    Amador County            8153          36
# Butte County                      Butte County           50426          49
# Calaveras County              Calaveras County           10046          37
# Colusa County                    Colusa County            3234          41
# Contra Costa County        Contra Costa County          416386          72
# Del Norte County              Del Norte County            4677          41
# El Dorado County              El Dorado County           51621          44
# Fresno County                    Fresno County          193025          53
# Glenn County                      Glenn County            3995          35
# Humboldt County                Humboldt County           44768          65
# Imperial County                Imperial County           34678          61
# Inyo County                        Inyo County            4634          49
# Kern County                        Kern County          133366          44
# Kings County                      Kings County           18699          43
# Lake County                        Lake County           14941          52
# Lassen County                    Lassen County            2799          23
# Los Angeles County          Los Angeles County         3028885          71
# Madera County                    Madera County           23168          43
# Marin County                      Marin County          128288          82
# Mariposa County                Mariposa County            4088          40
# Mendocino County              Mendocino County           28782          66
# Merced County                    Merced County           48991          54
# Modoc County                      Modoc County            1150          27
# Mono County                        Mono County            4013          60
# Monterey County                Monterey County          113953          70
# Napa County                        Napa County           49817          69
# Nevada County                    Nevada County           36359          56
# Orange County                    Orange County          814009          54
# Placer County                    Placer County          106869          46
# Plumas County                    Plumas County            4561          41
# Riverside County              Riverside County          527945          53
# Sacramento County            Sacramento County          440808          61
# San Benito County            San Benito County           17628          61
# San Bernardino County    San Bernardino County          455859          54
# San Diego County              San Diego County          964650          60
# San Francisco County      San Francisco County          378156          85
# San Joaquin County          San Joaquin County          161137          56
# San Luis Obispo County  San Luis Obispo County           88310          55
# San Mateo County              San Mateo County          291410          78
# Santa Barbara County      Santa Barbara County          129963          65
# Santa Clara County          Santa Clara County          617967          73
# Santa Cruz County            Santa Cruz County          114246          79
# Shasta County                    Shasta County           30000          32
# Sierra County                    Sierra County             730          38
# Siskiyou County                Siskiyou County            9593          41
# Solano County                    Solano County          131639          64
# Sonoma County                    Sonoma County          199938          75
# Stanislaus County            Stanislaus County          105841          49
# Sutter County                    Sutter County           17367          41
# Tehama County                    Tehama County            8911          31
# Trinity County                  Trinity County            2851          46
# Tulare County                    Tulare County           66105          45
# Tuolumne County                Tuolumne County           11978          39
# Ventura County                  Ventura County          251388          60
# Yolo County                        Yolo County           67598          70
# Yuba County                        Yuba County           11230          38
#
#                         Republican Votes  Republican %  Population  \
# Alameda County                    136309            18     1675900
# Alpine County                        244            33        1169
# Amador County                      13585            61       40099
# Butte County                       48730            48      208033
# Calaveras County                   16518            61       46112
# Colusa County                       4554            57       21676
# Contra Costa County               152877            26     1156530
# Del Norte County                    6461            56       27884
# El Dorado County                   61838            53      194940
# Fresno County                     164464            45     1006250
# Glenn County                        7063            63       28819
# Humboldt County                    21770            32      134872
# Imperial County                    20847            37      180907
# Inyo County                         4620            49       18132
# Kern County                       164484            54      906646
# Kings County                       24072            55      154498
# Lake County                        13123            46       64455
# Lassen County                       8970            75       30528
# Los Angeles County               1145530            27    10004300
# Madera County                      29378            55      157772
# Marin County                       24612            16      257990
# Mariposa County                     5950            58       17001
# Mendocino County                   13267            31       86097
# Merced County                      39397            44      281209
# Modoc County                        3109            72        8882
# Mono County                         2513            37       14485
# Monterey County                    46299            28      434172
# Napa County                        20676            29      136699
# Nevada County                      26779            41      100002
# Orange County                     676498            45     3175410
# Placer County                     122488            52      404328
# Plumas County                       6445            57       18873
# Riverside County                  448702            45     2495300
# Sacramento County                 259405            36     1565370
# San Benito County                  10590            37       64149
# San Bernardino County             366257            44     2193420
# San Diego County                  600094            38     3342800
# San Francisco County               56417            13      882402
# San Joaquin County                121098            42      771805
# San Luis Obispo County             67436            42      282868
# San Mateo County                   75563            20      764465
# Santa Barbara County               65736            33      447218
# Santa Clara County                214612            25     1923370
# Santa Cruz County                  26937            19      272585
# Shasta County                      60789            65      180451
# Sierra County                       1142            59        3013
# Siskiyou County                    13290            57       43528
# Solano County                      69306            34      449561
# Sonoma County                      61825            23      490029
# Stanislaus County                 104145            48      553194
# Sutter County                      24375            57       97594
# Tehama County                      19141            67       66150
# Trinity County                      3188            51       12003
# Tulare County                      77579            53      467801
# Tuolumne County                    17689            58       54569
# Ventura County                    162207            38      843870
# Yolo County                        27292            28      220882
# Yuba County                        17676            59       79779
#
#                         Population Density (per sq mi)  Total COVID-19 Cases
# Alameda County                                  1898.5                 40262
# Alpine County                                      1.6                     5
# Amador County                                     61.3                   823
# Butte County                                     132.1                  5765
# Calaveras County                                  43.3                   677
# Colusa County                                     18.5                  1050
# Contra Costa County                             1345.2                 33072
# Del Norte County                                  22.8                   605
# El Dorado County                                 101.6                  4412
# Fresno County                                    157.8                 49173
# Glenn County                                      21.1                  1254
# Humboldt County                                   33.3                  1374
# Imperial County                                   39.5                 20003
# Inyo County                                        1.8                   468
# Kern County                                      105.1                 55801
# Kings County                                     108.8                 14073
# Lake County                                       48.3                  1375
# Lassen County                                      7.1                  3732
# Los Angeles County                              2099.4                580325
# Madera County                                     70.8                  8441
# Marin County                                     310.1                  8801
# Mariposa County                                   12.3                   185
# Mendocino County                                  22.6                  2134
# Merced County                                    132.2                 14483
# Modoc County                                       2.2                   267
# Mono County                                        4.5                   488
# Monterey County                                  112.7                 18951
# Napa County                                      176.6                  4543
# Nevada County                                    101.3                  2173
# Orange County                                   3255.4                113783
# Placer County                                    240.6                 10554
# Plumas County                                      7.4                    94
# Riverside County                                 310.4                132818
# Sacramento County                               1459.0                 53185
# San Benito County                                 40.9                  2687
# San Bernardino County                            103.4                144455
# San Diego County                                 703.4                116852
# San Francisco County                            3575.3                 19603
# San Joaquin County                               491.4                 34641
# San Luis Obispo County                            75.8                  8269
# San Mateo County                                 998.5                 19645
# Santa Barbara County                             113.9                 14190
# Santa Clara County                              1412.2                 52414
# Santa Cruz County                                440.1                  6455
# Shasta County                                     46.4                  7000
# Sierra County                                      3.1                    32
# Siskiyou County                                    7.0                  1001
# Solano County                                    465.3                 14713
# Sonoma County                                    278.2                 15702
# Stanislaus County                                345.2                 28667
# Sutter County                                    156.2                  5369
# Tehama County                                     21.4                  2627
# Trinity County                                     4.2                   240
# Tulare County                                     93.2                 27790
# Tuolumne County                                   23.9                  2076
# Ventura County                                   378.5                 28643
# Yolo County                                      199.5                  6549
# Yuba County                                      113.5                  3212

# %% [markdown]
# # Automating the creation of matching pairs of counties
#
# ### Helper method to apply on each row to find pairs
# <br>
# We consider a county to be a pair if it satisfies the following conditions:
# <ol>
# <li>The Population is between 0.7 and 1.3 times the original</li>
# <li>The Population Density is between 0.4 and 1.6 times the original</li>
# <li>The corresponding voting percentage is at least 60% or greater for the opposite party</li>
# </ol>

# %%
def find_pairs(county, df):
    # Save relavant info on each county to find a similar pair
    dem_per = df.loc[county]['Democrat %']
    rep_per = df.loc[county]['Republican %']
    pop = df.loc[county]['Population']
    pop_dens = df.loc[county]['Population Density (per sq mi)']
    pairs = []
    
    # If it's a Democrat County, find a similar Republican County
    if dem_per >= 60:
        pairs = df.loc[ (df['Population'] > (pop * .7)) & (df['Population'] < (pop * 1.3)) & (df['Population Density (per sq mi)'] < (pop_dens * 1.6)) & (df['Population Density (per sq mi)'] > (pop_dens * 0.4)) & (df['Republican %'] > 60)]['County Name'].tolist()
    
    # If it's a Republican County, find a similar Democratic County
    elif rep_per >= 60:
        pairs = df.loc[ (df['Population'] > (pop * .7)) & (df['Population'] < (pop * 1.3)) & (df['Population Density (per sq mi)'] < (pop_dens * 1.6)) & (df['Population Density (per sq mi)'] > (pop_dens * 0.4)) & (df['Democrat %'] > 60)]['County Name'].tolist()
    
    # Return the found pairs as a list
    return pairs

# %% [markdown]
# ### Apply the method

# %%
for state in state_list:
    if state == 'Alaska':
        continue
    df_dictionary[state]['Pairing County'] = df_dictionary[state]['County Name'].apply(find_pairs, df=df_dictionary[state])

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df_dictionary['Georgia'])
# Out:
#                                County Name  Democrat Votes  Democrat %  \
# Appling County              Appling County            1784          21
# Atkinson County            Atkinson County             825          26
# Bacon County                  Bacon County             625          13
# Baker County                  Baker County             652          42
# Baldwin County              Baldwin County            9140          50
# Banks County                  Banks County             932          11
# Barrow County                Barrow County           10453          28
# Bartow County                Bartow County           12091          24
# Ben Hill County            Ben Hill County            2393          37
# Berrien County              Berrien County            1269          16
# Bibb County                    Bibb County           43408          61
# Bleckley County            Bleckley County            1312          23
# Brantley County            Brantley County             700           9
# Brooks County                Brooks County            2791          39
# Bryan County                  Bryan County            6738          32
# Bulloch County              Bulloch County           11248          37
# Burke County                  Burke County            5208          49
# Butts County                  Butts County            3274          28
# Calhoun County              Calhoun County            1263          58
# Camden County                Camden County            7967          34
# Candler County              Candler County            1269          29
# Carroll County              Carroll County           16236          30
# Catoosa County              Catoosa County            6932          21
# Charlton County            Charlton County            1105          24
# Chatham County              Chatham County           78247          59
# Chattahoochee County  Chattahoochee County             667          42
# Chattooga County          Chattooga County            1854          18
# Cherokee County            Cherokee County           42779          30
# Clarke County                Clarke County           36055          70
# Clay County                    Clay County             791          55
# Clayton County              Clayton County           95466          85
# Clinch County                Clinch County             744          26
# Cobb County                    Cobb County          221847          56
# Coffee County                Coffee County            4511          30
# Colquitt County            Colquitt County            4190          26
# Columbia County            Columbia County           29232          36
# Cook County                    Cook County            2059          29
# Coweta County                Coweta County           24210          32
# Crawford County            Crawford County            1615          27
# Crisp County                  Crisp County            2982          37
# Dade County                    Dade County            1261          17
# Dawson County                Dawson County            2486          16
# DeKalb County                DeKalb County          308162          83
# Decatur County              Decatur County            4782          41
# Dodge County                  Dodge County            2172          27
# Dooly County                  Dooly County            1911          47
# Dougherty County          Dougherty County           24568          70
# Douglas County              Douglas County           42814          62
# Early County                  Early County            2450          47
# Echols County                Echols County             167          12
# Effingham County          Effingham County            7718          24
# Elbert County                Elbert County            2879          31
# Emanuel County              Emanuel County            2886          30
# Evans County                  Evans County            1324          31
# Fannin County                Fannin County            2570          17
# Fayette County              Fayette County           33062          46
# Floyd County                  Floyd County           11917          29
# Forsyth County              Forsyth County           42208          33
# Franklin County            Franklin County            1593          15
# Fulton County                Fulton County          380212          73
# Gilmer County                Gilmer County            2932          18
# Glascock County            Glascock County             155          10
# Glynn County                  Glynn County           15882          38
# Gordon County                Gordon County            4384          18
# Grady County                  Grady County            3619          34
# Greene County                Greene County            4087          36
# Gwinnett County            Gwinnett County          241994          58
# Habersham County          Habersham County            3562          17
# Hall County                    Hall County           25033          28
# Hancock County              Hancock County            2976          72
# Haralson County            Haralson County            1791          13
# Harris County                Harris County            5457          27
# Hart County                    Hart County            3157          25
# Heard County                  Heard County             824          15
# Henry County                  Henry County           73443          60
# Houston County              Houston County           32239          43
# Irwin County                  Irwin County            1008          24
# Jackson County              Jackson County            7642          20
# Jasper County                Jasper County            1761          23
# Jeff Davis County        Jeff Davis County            1028          18
# Jefferson County          Jefferson County            4058          53
# Jenkins County              Jenkins County            1266          37
# Johnson County              Johnson County            1222          30
# Jones County                  Jones County            4882          33
# Lamar County                  Lamar County            2620          29
# Lanier County                Lanier County            1019          29
# Laurens County              Laurens County            8074          36
# Lee County                      Lee County            4558          27
# Liberty County              Liberty County           13104          61
# Lincoln County              Lincoln County            1432          31
# Long County                    Long County            2035          36
# Lowndes County              Lowndes County           20116          43
# Lumpkin County              Lumpkin County            3126          20
# Macon County                  Macon County            2858          61
# Madison County              Madison County            3411          23
# Marion County                Marion County            1312          36
# McDuffie County            McDuffie County            4168          40
# McIntosh County            McIntosh County            2612          39
# Meriwether County        Meriwether County            4287          39
# Miller County                Miller County             748          26
# Mitchell County            Mitchell County            3993          45
# Monroe County                Monroe County            4385          28
# Montgomery County        Montgomery County             980          25
# Morgan County                Morgan County            3353          29
# Murray County                Murray County            2301          15
# Muscogee County            Muscogee County           49446          61
# Newton County                Newton County           29789          55
# Oconee County                Oconee County            8162          32
# Oglethorpe County        Oglethorpe County            2439          30
# Paulding County            Paulding County           29695          35
# Peach County                  Peach County            5922          47
# Pickens County              Pickens County            2824          17
# Pierce County                Pierce County            1100          12
# Pike County                    Pike County            1505          14
# Polk County                    Polk County            3657          21
# Pulaski County              Pulaski County            1230          30
# Putnam County                Putnam County            3448          29
# Quitman County              Quitman County             497          45
# Rabun County                  Rabun County            1984          21
# Randolph County            Randolph County            1671          54
# Richmond County            Richmond County           59119          68
# Rockdale County            Rockdale County           31237          70
# Schley County                Schley County             462          20
# Screven County              Screven County            2661          40
# Seminole County            Seminole County            1256          32
# Spalding County            Spalding County           11828          39
# Stephens County            Stephens County            2386          20
# Stewart County              Stewart County            1182          59
# Sumter County                Sumter County            6314          52
# Talbot County                Talbot County            2114          60
# Taliaferro County        Taliaferro County             561          61
# Tattnall County            Tattnall County            2062          25
# Taylor County                Taylor County            1388          36
# Telfair County              Telfair County            1488          34
# Terrell County              Terrell County            2376          54
# Thomas County                Thomas County            8708          40
# Tift County                    Tift County            5318          33
# Toombs County                Toombs County            2938          27
# Towns County                  Towns County            1550          19
# Treutlen County            Treutlen County             952          31
# Troup County                  Troup County           11577          39
# Turner County                Turner County            1409          37
# Twiggs County                Twiggs County            2044          46
# Union County                  Union County            2800          18
# Upson County                  Upson County            4203          33
# Walker County                Walker County            5770          20
# Walton County                Walton County           12683          25
# Ware County                    Ware County            4169          29
# Warren County                Warren County            1468          55
# Washington County        Washington County            4743          50
# Wayne County                  Wayne County            2688          21
# Webster County              Webster County             640          46
# Wheeler County              Wheeler County             689          30
# White County                  White County            2411          16
# Whitfield County          Whitfield County           10680          29
# Wilcox County                Wilcox County             861          26
# Wilkes County                Wilkes County            2160          43
# Wilkinson County          Wilkinson County            2074          44
# Worth County                  Worth County            2395          26
#
#                       Republican Votes  Republican %  Population  \
# Appling County                    6570            78       18246
# Atkinson County                   2300            73        8068
# Bacon County                      4017            86       11196
# Baker County                       897            58        2990
# Baldwin County                    8903            49       44887
# Banks County                      7795            89       19496
# Barrow County                    26804            71       85646
# Bartow County                    37672            75      109098
# Ben Hill County                   4111            63       16578
# Berrien County                    6419            83       19528
# Bibb County                      26559            38      153415
# Bleckley County                   4329            76       12925
# Brantley County                   6993            90       19233
# Brooks County                     4261            60       15435
# Bryan County                     14240            67       41195
# Bulloch County                   18387            61       81974
# Burke County                      5400            51       22327
# Butts County                      8406            71       25680
# Calhoun County                     923            42        6025
# Camden County                    15249            64       55681
# Candler County                    3133            71       10779
# Carroll County                   37476            69      121987
# Catoosa County                   25167            77       67780
# Charlton County                   3419            75       13865
# Chatham County                   53232            40      289694
# Chattahoochee County               880            56       11214
# Chattooga County                  8064            80       24796
# Cherokee County                  99585            69      263632
# Clarke County                    14450            28      129394
# Clay County                        637            44        2784
# Clayton County                   15811            14      295315
# Clinch County                     2105            74        6633
# Cobb County                     165436            42      764212
# Coffee County                    10578            70       43491
# Colquitt County                  11777            73       45745
# Columbia County                  50013            62      159351
# Cook County                       4900            70       17369
# Coweta County                    51501            67      151020
# Crawford County                   4428            73       12474
# Crisp County                      4985            62       22127
# Dade County                       6066            82       16005
# Dawson County                    13398            83       27089
# DeKalb County                    58377            16      763688
# Decatur County                    6755            58       26235
# Dodge County                      5843            72       20417
# Dooly County                      2159            53       13071
# Dougherty County                 10441            30       86712
# Douglas County                   25454            37      147662
# Early County                      2710            52       10094
# Echols County                     1256            87        4012
# Effingham County                 23361            74       66364
# Elbert County                     6226            68       19293
# Emanuel County                    6553            69       22685
# Evans County                      2888            68       10606
# Fannin County                    12169            82       26395
# Fayette County                   37956            53      115661
# Floyd County                     28906            70       99032
# Forsyth County                   85123            66      251511
# Franklin County                   9069            84       23664
# Fulton County                   137247            26     1077740
# Gilmer County                    13429            81       31903
# Glascock County                   1402            90        2965
# Glynn County                     25617            61       85609
# Gordon County                    19405            81       58298
# Grady County                      7034            66       24492
# Greene County                     7066            63       18915
# Gwinnett County                 166400            40      945163
# Habersham County                 16637            81       45283
# Hall County                      64183            71      207344
# Hancock County                    1154            28        8546
# Haralson County                  12330            87       30023
# Harris County                    14319            72       35912
# Hart County                       9465            74       26339
# Heard County                      4519            84       11975
# Henry County                     48259            39      239394
# Houston County                   41540            56      160203
# Irwin County                      3134            75        9436
# Jackson County                   29502            78       75629
# Jasper County                     5822            76       14409
# Jeff Davis County                 4695            81       15182
# Jefferson County                  3537            46       15300
# Jenkins County                    2161            63        8587
# Johnson County                    2850            70        9580
# Jones County                      9940            67       28790
# Lamar County                      6331            70       19193
# Lanier County                     2509            70       10491
# Laurens County                   14493            64       47756
# Lee County                       12007            72       30233
# Liberty County                    7959            37       62264
# Lincoln County                    3173            68        7917
# Long County                       3527            62       20027
# Lowndes County                   25692            55      118503
# Lumpkin County                   12163            78       34321
# Macon County                      1783            38       12734
# Madison County                   11326            76       30118
# Marion County                     2275            63        8345
# McDuffie County                   6169            59       21092
# McIntosh County                   4016            60       14434
# Meriwether County                 6524            60       21240
# Miller County                     2066            73        5752
# Mitchell County                   4935            55       21591
# Monroe County                    11057            71       27653
# Montgomery County                 2960            75        9176
# Morgan County                     8231            70       19721
# Murray County                    12944            84       40249
# Muscogee County                  30107            37      197369
# Newton County                    23869            44      114067
# Oconee County                    16595            66       41082
# Oglethorpe County                 5592            69       15438
# Paulding County                  54517            64      173281
# Peach County                      6506            52       27729
# Pickens County                   14110            82       33168
# Pierce County                     7898            87       19542
# Pike County                       9127            85       19277
# Polk County                      13587            78       42880
# Pulaski County                    2815            69       11194
# Putnam County                     8291            70       22418
# Quitman County                     604            55        2338
# Rabun County                      7474            78       17417
# Randolph County                   1390            45        6744
# Richmond County                  26780            31      203369
# Rockdale County                  13014            29       91287
# Schley County                     1800            79        5284
# Screven County                    3915            59       13972
# Seminole County                   2613            67        7910
# Spalding County                  18104            60       67299
# Stephens County                   9367            79       25843
# Stewart County                     801            40        6807
# Sumter County                     5733            47       29252
# Talbot County                     1392            40        6100
# Taliaferro County                  360            39        1462
# Tattnall County                   6054            74       25087
# Taylor County                     2420            63        8020
# Telfair County                    2825            65       15746
# Terrell County                    2004            45        8475
# Thomas County                    12969            59       44568
# Tift County                      10784            66       40746
# Toombs County                     7873            72       26758
# Towns County                      6384            80       12208
# Treutlen County                   2101            68        6989
# Troup County                     18142            60       69766
# Turner County                     2349            62        8062
# Twiggs County                     2370            53        8066
# Union County                     12650            81       25117
# Upson County                      8606            67       26455
# Walker County                    23173            79       70079
# Walton County                    37839            74       95984
# Ware County                       9903            70       35881
# Warren County                     1166            44        5261
# Washington County                 4668            49       20338
# Wayne County                      9987            78       30044
# Webster County                     748            54        2608
# Wheeler County                    1583            69        7812
# White County                     12222            83       31608
# Whitfield County                 25644            70      105007
# Wilcox County                     2402            73        8443
# Wilkes County                     2823            56        9690
# Wilkinson County                  2665            56        8865
# Worth County                      6830            74       20192
#
#                       Population Density (per sq mi)  Total COVID-19 Cases  \
# Appling County                                  36.0                  1322
# Atkinson County                                 24.1                   568
# Bacon County                                    39.2                   706
# Baker County                                     9.6                   116
# Baldwin County                                 171.5                  2691
# Banks County                                    78.3                   980
# Barrow County                                  435.0                  4006
# Bartow County                                  214.4                  5530
# Ben Hill County                                 69.1                  1095
# Berrien County                                  41.7                   685
# Bibb County                                    607.9                  8335
# Bleckley County                                 58.9                   592
# Brantley County                                 41.3                   602
# Brooks County                                   31.7                   706
# Bryan County                                    70.8                  1599
# Bulloch County                                 104.5                  3496
# Burke County                                    27.7                  1081
# Butts County                                   124.8                  1098
# Calhoun County                                  23.1                   313
# Camden County                                   65.5                  1998
# Candler County                                  44.4                   589
# Carroll County                                 222.0                  4754
# Catoosa County                                 399.8                  2705
# Charlton County                                 16.7                   769
# Chatham County                                 435.4                 11718
# Chattahoochee County                            47.2                  2128
# Chattooga County                                81.3                  1357
# Cherokee County                                510.9                 10827
# Clarke County                                  988.8                  7686
# Clay County                                     14.3                   137
# Clayton County                                1830.7                 11715
# Clinch County                                    8.2                   511
# Cobb County                                   2057.7                 31565
# Coffee County                                   71.3                  3038
# Colquitt County                                 82.6                  2409
# Columbia County                                430.3                  6330
# Cook County                                     73.2                   891
# Coweta County                                  294.8                  4362
# Crawford County                                 38.4                   282
# Crisp County                                    83.3                   875
# Dade County                                     94.9                   621
# Dawson County                                  104.9                  1384
# DeKalb County                                 2608.2                 30716
# Decatur County                                  44.1                  1497
# Dodge County                                    42.5                   776
# Dooly County                                    36.4                   488
# Dougherty County                               280.6                  3711
# Douglas County                                 671.7                  5923
# Early County                                    20.6                   659
# Echols County                                    9.6                   299
# Effingham County                               111.1                  2243
# Elbert County                                   52.6                  1058
# Emanuel County                                  32.9                  1323
# Evans County                                    58.2                   548
# Fannin County                                   60.3                  1162
# Fayette County                                 541.5                  3196
# Floyd County                                   185.4                  5972
# Forsyth County                                 765.9                  7767
# Franklin County                                 82.8                  1404
# Fulton County                                 1809.9                 44255
# Gilmer County                                   66.0                  1412
# Glascock County                                 21.4                    76
# Glynn County                                   138.3                  4407
# Gordon County                                  155.5                  3599
# Grady County                                    54.8                   976
# Greene County                                   39.9                   758
# Gwinnett County                               1928.0                 44202
# Habersham County                               155.3                  2952
# Hall County                                    431.7                 15016
# Hancock County                                  18.9                   536
# Haralson County                                100.9                  1072
# Harris County                                   68.8                  1091
# Hart County                                     98.9                   926
# Heard County                                    38.8                   377
# Henry County                                   640.2                  9320
# Houston County                                 383.3                  5073
# Irwin County                                    26.1                   477
# Jackson County                                 177.6                  4124
# Jasper County                                   36.5                   346
# Jeff Davis County                               44.8                   893
# Jefferson County                                31.3                  1055
# Jenkins County                                  24.9                   500
# Johnson County                                  32.1                   501
# Jones County                                    72.8                   863
# Lamar County                                    97.5                   676
# Lanier County                                   51.8                   366
# Laurens County                                  58.7                  2438
# Lee County                                      79.6                   929
# Liberty County                                 107.0                  1648
# Lincoln County                                  30.3                   303
# Long County                                     39.5                   362
# Lowndes County                                 220.4                  5714
# Lumpkin County                                 108.1                  1575
# Macon County                                    35.1                   333
# Madison County                                  98.5                  1337
# Marion County                                   23.8                   234
# McDuffie County                                 80.9                   891
# McIntosh County                                 24.7                   416
# Meriwether County                               42.4                   717
# Miller County                                   21.2                   382
# Mitchell County                                 45.1                   994
# Monroe County                                   67.3                  1071
# Montgomery County                               36.8                   425
# Morgan County                                   50.4                   675
# Murray County                                  113.7                  2215
# Muscogee County                                897.0                  7832
# Newton County                                  363.6                  4044
# Oconee County                                  181.2                  1290
# Oglethorpe County                               33.2                   605
# Paulding County                                463.1                  4980
# Peach County                                   180.7                  1054
# Pickens County                                 127.0                  1268
# Pierce County                                   54.9                   799
# Pike County                                     81.2                   549
# Polk County                                    132.2                  2224
# Pulaski County                                  46.5                   412
# Putnam County                                   58.8                  1030
# Quitman County                                  15.0                    47
# Rabun County                                    43.2                   818
# Randolph County                                 17.2                   349
# Richmond County                                612.4                 11279
# Rockdale County                                653.0                  3135
# Schley County                                   30.1                   143
# Screven County                                  21.8                   489
# Seminole County                                 34.3                   522
# Spalding County                                320.4                  2273
# Stephens County                                139.7                  1871
# Stewart County                                  12.7                   597
# Sumter County                                   64.6                  1180
# Talbot County                                   16.7                   222
# Taliaferro County                                8.7                    43
# Tattnall County                                 51.9                  1128
# Taylor County                                   22.4                   316
# Telfair County                                  37.1                   552
# Terrell County                                  27.6                   410
# Thomas County                                   81.0                  2021
# Tift County                                    151.5                  2662
# Toombs County                                   73.5                  1817
# Towns County                                    62.0                   640
# Treutlen County                                 33.5                   353
# Troup County                                   153.3                  3645
# Turner County                                   29.3                   427
# Twiggs County                                   23.7                   294
# Union County                                    65.5                  1219
# Upson County                                    81.5                  1013
# Walker County                                  153.1                  3233
# Walton County                                  258.7                  3636
# Ware County                                     39.6                  2005
# Warren County                                   19.6                   203
# Washington County                               30.5                  1074
# Wayne County                                    46.5                  1611
# Webster County                                  13.1                    49
# Wheeler County                                  26.4                   378
# White County                                   113.9                  1668
# Whitfield County                               354.3                  9424
# Wilcox County                                   23.7                   329
# Wilkes County                                   21.4                   410
# Wilkinson County                                20.9                   466
# Worth County                                    37.2                   747
#
#                                                          Pairing County
# Appling County                                                       []
# Atkinson County                                        [Hancock County]
# Bacon County                             [Hancock County, Macon County]
# Baker County                                                         []
# Baldwin County                                                       []
# Banks County                                                         []
# Barrow County                       [Dougherty County, Rockdale County]
# Bartow County                                        [Dougherty County]
# Ben Hill County                                          [Macon County]
# Berrien County                                                       []
# Bibb County           [Columbia County, Coweta County, Paulding County]
# Bleckley County                                          [Macon County]
# Brantley County                                                      []
# Brooks County                                            [Macon County]
# Bryan County                                                         []
# Bulloch County                                         [Liberty County]
# Burke County                                                         []
# Butts County                                                         []
# Calhoun County                                                       []
# Camden County                                                        []
# Candler County                           [Hancock County, Macon County]
# Carroll County                                       [Dougherty County]
# Catoosa County                                       [Dougherty County]
# Charlton County                                                      []
# Chatham County                                                       []
# Chattahoochee County                                                 []
# Chattooga County                                                     []
# Cherokee County                                       [Richmond County]
# Clarke County                                         [Columbia County]
# Clay County                                                          []
# Clayton County                                         [Forsyth County]
# Clinch County                                                        []
# Cobb County                                                          []
# Coffee County                                                        []
# Colquitt County                                                      []
# Columbia County          [Bibb County, Douglas County, Richmond County]
# Cook County                                              [Macon County]
# Coweta County                                                        []
# Crawford County                                          [Macon County]
# Crisp County                                                         []
# Dade County                                                          []
# Dawson County                                                        []
# DeKalb County                                                        []
# Decatur County                                                       []
# Dodge County                                                         []
# Dooly County                                                         []
# Dougherty County      [Barrow County, Bartow County, Catoosa County,...
# Douglas County        [Columbia County, Coweta County, Paulding Coun...
# Early County                                                         []
# Echols County                                                        []
# Effingham County                                       [Liberty County]
# Elbert County                                                        []
# Emanuel County                                                       []
# Evans County                                             [Macon County]
# Fannin County                                                        []
# Fayette County                                                       []
# Floyd County                                         [Dougherty County]
# Forsyth County                       [Muscogee County, Richmond County]
# Franklin County                                                      []
# Fulton County                                                        []
# Gilmer County                                                        []
# Glascock County                                                      []
# Glynn County                                           [Liberty County]
# Gordon County                                          [Liberty County]
# Grady County                                                         []
# Greene County                                                        []
# Gwinnett County                                                      []
# Habersham County                                                     []
# Hall County              [Bibb County, Douglas County, Richmond County]
# Hancock County        [Atkinson County, Clinch County, Irwin County,...
# Haralson County                                                      []
# Harris County                                                        []
# Hart County                                                          []
# Heard County                             [Hancock County, Macon County]
# Henry County          [Cherokee County, Forsyth County, Hall County,...
# Houston County                                                       []
# Irwin County                                           [Hancock County]
# Jackson County                       [Dougherty County, Liberty County]
# Jasper County                                            [Macon County]
# Jeff Davis County                                        [Macon County]
# Jefferson County                                                     []
# Jenkins County                                         [Hancock County]
# Johnson County                                         [Hancock County]
# Jones County                                                         []
# Lamar County                                                         []
# Lanier County                                            [Macon County]
# Laurens County                                                       []
# Lee County                                                           []
# Liberty County        [Camden County, Colquitt County, Effingham Cou...
# Lincoln County                                         [Hancock County]
# Long County                                                          []
# Lowndes County                                                       []
# Lumpkin County                                                       []
# Macon County          [Bacon County, Candler County, Charlton County...
# Madison County                                                       []
# Marion County                                          [Hancock County]
# McDuffie County                                                      []
# McIntosh County                                          [Macon County]
# Meriwether County                                                    []
# Miller County                                                        []
# Mitchell County                                                      []
# Monroe County                                                        []
# Montgomery County                                      [Hancock County]
# Morgan County                                                        []
# Murray County                                                        []
# Muscogee County       [Columbia County, Forsyth County, Hall County,...
# Newton County                                                        []
# Oconee County                                                        []
# Oglethorpe County                                        [Macon County]
# Paulding County          [Bibb County, Douglas County, Richmond County]
# Peach County                                                         []
# Pickens County                                                       []
# Pierce County                                                        []
# Pike County                                                          []
# Polk County                                                          []
# Pulaski County                           [Hancock County, Macon County]
# Putnam County                                                        []
# Quitman County                                                       []
# Rabun County                                             [Macon County]
# Randolph County                                                      []
# Richmond County       [Cherokee County, Columbia County, Coweta Coun...
# Rockdale County       [Barrow County, Catoosa County, Whitfield County]
# Schley County                                                        []
# Screven County                                                       []
# Seminole County                                        [Hancock County]
# Spalding County                                      [Dougherty County]
# Stephens County                                                      []
# Stewart County                                                       []
# Sumter County                                                        []
# Talbot County            [Clinch County, Miller County, Wheeler County]
# Taliaferro County                                                    []
# Tattnall County                                                      []
# Taylor County                                          [Hancock County]
# Telfair County                                           [Macon County]
# Terrell County                                                       []
# Thomas County                                                        []
# Tift County                                                          []
# Toombs County                                                        []
# Towns County                                             [Macon County]
# Treutlen County                                        [Hancock County]
# Troup County                                           [Liberty County]
# Turner County                                          [Hancock County]
# Twiggs County                                                        []
# Union County                                                         []
# Upson County                                                         []
# Walker County                                          [Liberty County]
# Walton County                                        [Dougherty County]
# Ware County                                                          []
# Warren County                                                        []
# Washington County                                                    []
# Wayne County                                                         []
# Webster County                                                       []
# Wheeler County                                         [Hancock County]
# White County                                                         []
# Whitfield County                                     [Dougherty County]
# Wilcox County                                          [Hancock County]
# Wilkes County                                                        []
# Wilkinson County                                                     []
# Worth County                                                         []

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(df_dictionary['California'])
# Out:
#                                    County Name  Democrat Votes  Democrat %  \
# Alameda County                  Alameda County          617659          80
# Alpine County                    Alpine County             476          64
# Amador County                    Amador County            8153          36
# Butte County                      Butte County           50426          49
# Calaveras County              Calaveras County           10046          37
# Colusa County                    Colusa County            3234          41
# Contra Costa County        Contra Costa County          416386          72
# Del Norte County              Del Norte County            4677          41
# El Dorado County              El Dorado County           51621          44
# Fresno County                    Fresno County          193025          53
# Glenn County                      Glenn County            3995          35
# Humboldt County                Humboldt County           44768          65
# Imperial County                Imperial County           34678          61
# Inyo County                        Inyo County            4634          49
# Kern County                        Kern County          133366          44
# Kings County                      Kings County           18699          43
# Lake County                        Lake County           14941          52
# Lassen County                    Lassen County            2799          23
# Los Angeles County          Los Angeles County         3028885          71
# Madera County                    Madera County           23168          43
# Marin County                      Marin County          128288          82
# Mariposa County                Mariposa County            4088          40
# Mendocino County              Mendocino County           28782          66
# Merced County                    Merced County           48991          54
# Modoc County                      Modoc County            1150          27
# Mono County                        Mono County            4013          60
# Monterey County                Monterey County          113953          70
# Napa County                        Napa County           49817          69
# Nevada County                    Nevada County           36359          56
# Orange County                    Orange County          814009          54
# Placer County                    Placer County          106869          46
# Plumas County                    Plumas County            4561          41
# Riverside County              Riverside County          527945          53
# Sacramento County            Sacramento County          440808          61
# San Benito County            San Benito County           17628          61
# San Bernardino County    San Bernardino County          455859          54
# San Diego County              San Diego County          964650          60
# San Francisco County      San Francisco County          378156          85
# San Joaquin County          San Joaquin County          161137          56
# San Luis Obispo County  San Luis Obispo County           88310          55
# San Mateo County              San Mateo County          291410          78
# Santa Barbara County      Santa Barbara County          129963          65
# Santa Clara County          Santa Clara County          617967          73
# Santa Cruz County            Santa Cruz County          114246          79
# Shasta County                    Shasta County           30000          32
# Sierra County                    Sierra County             730          38
# Siskiyou County                Siskiyou County            9593          41
# Solano County                    Solano County          131639          64
# Sonoma County                    Sonoma County          199938          75
# Stanislaus County            Stanislaus County          105841          49
# Sutter County                    Sutter County           17367          41
# Tehama County                    Tehama County            8911          31
# Trinity County                  Trinity County            2851          46
# Tulare County                    Tulare County           66105          45
# Tuolumne County                Tuolumne County           11978          39
# Ventura County                  Ventura County          251388          60
# Yolo County                        Yolo County           67598          70
# Yuba County                        Yuba County           11230          38
#
#                         Republican Votes  Republican %  Population  \
# Alameda County                    136309            18     1675900
# Alpine County                        244            33        1169
# Amador County                      13585            61       40099
# Butte County                       48730            48      208033
# Calaveras County                   16518            61       46112
# Colusa County                       4554            57       21676
# Contra Costa County               152877            26     1156530
# Del Norte County                    6461            56       27884
# El Dorado County                   61838            53      194940
# Fresno County                     164464            45     1006250
# Glenn County                        7063            63       28819
# Humboldt County                    21770            32      134872
# Imperial County                    20847            37      180907
# Inyo County                         4620            49       18132
# Kern County                       164484            54      906646
# Kings County                       24072            55      154498
# Lake County                        13123            46       64455
# Lassen County                       8970            75       30528
# Los Angeles County               1145530            27    10004300
# Madera County                      29378            55      157772
# Marin County                       24612            16      257990
# Mariposa County                     5950            58       17001
# Mendocino County                   13267            31       86097
# Merced County                      39397            44      281209
# Modoc County                        3109            72        8882
# Mono County                         2513            37       14485
# Monterey County                    46299            28      434172
# Napa County                        20676            29      136699
# Nevada County                      26779            41      100002
# Orange County                     676498            45     3175410
# Placer County                     122488            52      404328
# Plumas County                       6445            57       18873
# Riverside County                  448702            45     2495300
# Sacramento County                 259405            36     1565370
# San Benito County                  10590            37       64149
# San Bernardino County             366257            44     2193420
# San Diego County                  600094            38     3342800
# San Francisco County               56417            13      882402
# San Joaquin County                121098            42      771805
# San Luis Obispo County             67436            42      282868
# San Mateo County                   75563            20      764465
# Santa Barbara County               65736            33      447218
# Santa Clara County                214612            25     1923370
# Santa Cruz County                  26937            19      272585
# Shasta County                      60789            65      180451
# Sierra County                       1142            59        3013
# Siskiyou County                    13290            57       43528
# Solano County                      69306            34      449561
# Sonoma County                      61825            23      490029
# Stanislaus County                 104145            48      553194
# Sutter County                      24375            57       97594
# Tehama County                      19141            67       66150
# Trinity County                      3188            51       12003
# Tulare County                      77579            53      467801
# Tuolumne County                    17689            58       54569
# Ventura County                    162207            38      843870
# Yolo County                        27292            28      220882
# Yuba County                        17676            59       79779
#
#                         Population Density (per sq mi)  Total COVID-19 Cases  \
# Alameda County                                  1898.5                 40262
# Alpine County                                      1.6                     5
# Amador County                                     61.3                   823
# Butte County                                     132.1                  5765
# Calaveras County                                  43.3                   677
# Colusa County                                     18.5                  1050
# Contra Costa County                             1345.2                 33072
# Del Norte County                                  22.8                   605
# El Dorado County                                 101.6                  4412
# Fresno County                                    157.8                 49173
# Glenn County                                      21.1                  1254
# Humboldt County                                   33.3                  1374
# Imperial County                                   39.5                 20003
# Inyo County                                        1.8                   468
# Kern County                                      105.1                 55801
# Kings County                                     108.8                 14073
# Lake County                                       48.3                  1375
# Lassen County                                      7.1                  3732
# Los Angeles County                              2099.4                580325
# Madera County                                     70.8                  8441
# Marin County                                     310.1                  8801
# Mariposa County                                   12.3                   185
# Mendocino County                                  22.6                  2134
# Merced County                                    132.2                 14483
# Modoc County                                       2.2                   267
# Mono County                                        4.5                   488
# Monterey County                                  112.7                 18951
# Napa County                                      176.6                  4543
# Nevada County                                    101.3                  2173
# Orange County                                   3255.4                113783
# Placer County                                    240.6                 10554
# Plumas County                                      7.4                    94
# Riverside County                                 310.4                132818
# Sacramento County                               1459.0                 53185
# San Benito County                                 40.9                  2687
# San Bernardino County                            103.4                144455
# San Diego County                                 703.4                116852
# San Francisco County                            3575.3                 19603
# San Joaquin County                               491.4                 34641
# San Luis Obispo County                            75.8                  8269
# San Mateo County                                 998.5                 19645
# Santa Barbara County                             113.9                 14190
# Santa Clara County                              1412.2                 52414
# Santa Cruz County                                440.1                  6455
# Shasta County                                     46.4                  7000
# Sierra County                                      3.1                    32
# Siskiyou County                                    7.0                  1001
# Solano County                                    465.3                 14713
# Sonoma County                                    278.2                 15702
# Stanislaus County                                345.2                 28667
# Sutter County                                    156.2                  5369
# Tehama County                                     21.4                  2627
# Trinity County                                     4.2                   240
# Tulare County                                     93.2                 27790
# Tuolumne County                                   23.9                  2076
# Ventura County                                   378.5                 28643
# Yolo County                                      199.5                  6549
# Yuba County                                      113.5                  3212
#
#                                             Pairing County
# Alameda County                                          []
# Alpine County                                           []
# Amador County                                           []
# Butte County                                            []
# Calaveras County                                        []
# Colusa County                                           []
# Contra Costa County                                     []
# Del Norte County                                        []
# El Dorado County                                        []
# Fresno County                                           []
# Glenn County                                            []
# Humboldt County                                         []
# Imperial County                            [Shasta County]
# Inyo County                                             []
# Kern County                                             []
# Kings County                                            []
# Lake County                                             []
# Lassen County                                           []
# Los Angeles County                                      []
# Madera County                                           []
# Marin County                                            []
# Mariposa County                                         []
# Mendocino County                           [Tehama County]
# Merced County                                           []
# Modoc County                                            []
# Mono County                                             []
# Monterey County                                         []
# Napa County                                             []
# Nevada County                                           []
# Orange County                                           []
# Placer County                                           []
# Plumas County                                           []
# Riverside County                                        []
# Sacramento County                                       []
# San Benito County        [Calaveras County, Tehama County]
# San Bernardino County                                   []
# San Diego County                                        []
# San Francisco County                                    []
# San Joaquin County                                      []
# San Luis Obispo County                                  []
# San Mateo County                                        []
# Santa Barbara County                                    []
# Santa Clara County                                      []
# Santa Cruz County                                       []
# Shasta County           [Humboldt County, Imperial County]
# Sierra County                                           []
# Siskiyou County                                         []
# Solano County                                           []
# Sonoma County                                           []
# Stanislaus County                                       []
# Sutter County                                           []
# Tehama County                                           []
# Trinity County                                          []
# Tulare County                                           []
# Tuolumne County                                         []
# Ventura County                                          []
# Yolo County                                             []
# Yuba County                                             []

# %%
import babypandas as bpd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import numpy as np

import otter
import numbers
import IPython

# %% [markdown]
# ### Red State: Florida    (A Red state is a state where most of the people in the state supports republican)

# %%
#Load the DataFrame for Florida
Florida = df_dictionary['Florida']
Florida
# Out:
#                          County Name  Democrat Votes  Democrat %  \
# Alachua County        Alachua County           89704          63
# Baker County            Baker County            2037          15
# Bay County                Bay County           25614          28
# Bradford County      Bradford County            3160          23
# Brevard County        Brevard County          148549          41
# ...                              ...             ...         ...
# Union County            Union County            1053          17
# Volusia County        Volusia County          130575          43
# Wakulla County        Wakulla County            5351          29
# Walton County          Walton County           10338          24
# Washington County  Washington County            2347          19
#
#                    Republican Votes  Republican %  Population  \
# Alachua County                50972            36      269235
# Baker County                  11911            85       30067
# Bay County                    66097            71      163170
# Bradford County               10334            76       28650
# Brevard County               207883            58      608681
# ...                             ...           ...         ...
# Union County                   5133            82       15146
# Volusia County               173821            57      560467
# Wakulla County                12874            70       35065
# Walton County                 32947            75       77410
# Washington County              9876            80       26153
#
#                    Population Density (per sq mi)  Total COVID-19 Cases  \
# Alachua County                              259.9                 14468
# Baker County                                 45.9                  2246
# Bay County                                  167.4                 10295
# Bradford County                              91.7                  1674
# Brevard County                              352.5                 18511
# ...                                           ...                   ...
# Union County                                 61.1                  1342
# Volusia County                              348.3                 19334
# Wakulla County                               42.2                  1852
# Walton County                                46.6                  4320
# Washington County                            40.0                  1744
#
#                                                       Pairing County
# Alachua County     [Charlotte County, Clay County, Hernando Count...
# Baker County                                                      []
# Bay County                                                        []
# Bradford County                                                   []
# Brevard County                                                    []
# ...                                                              ...
# Union County                                                      []
# Volusia County                                                    []
# Wakulla County                                                    []
# Walton County                                                     []
# Washington County                                                 []
#
# [67 rows x 9 columns]

# %% [markdown]
# ***First Pair: Palm Beach County( Dem) & Pasco County (Rep)***

# %%
Flopair01 = Florida[(Florida.get('County Name') == 'Palm Beach County' ) | (Florida.get('County Name') == 'Pasco County' )]
Flopair01
# Out:
#                          County Name  Democrat Votes  Democrat %  \
# Palm Beach County  Palm Beach County          433572          56
# Pasco County            Pasco County          119073          39
#
#                    Republican Votes  Republican %  Population  \
# Palm Beach County            334711            43     1510660
# Pasco County                 179621            60      568804
#
#                    Population Density (per sq mi)  Total COVID-19 Cases  \
# Palm Beach County                           570.3                 74789
# Pasco County                                544.4                 18733
#
#                   Pairing County
# Palm Beach County             []
# Pasco County                  []

# %%
ax = Flopair01.plot.barh(x = 'County Name', y = 'Total COVID-19 Cases', color = ['blue', 'red'], legend = None)
ax.set_xlabel("Total COVID-19 Cases")
# Out:
# Text(0.5, 0, 'Total COVID-19 Cases')

# %%
print('The total COVID-19 Cases differences between Democratic and Republican is', Flopair01.get('Total COVID-19 Cases').iloc[0] - Flopair01.get('Total COVID-19 Cases').iloc[1],'. Therefore, Republican is having a good influence to the control of Covid spreading.')
# Out:
# The total COVID-19 Cases differences between Democratic and Republican is 56056 . Therefore, Republican is having a good influence to the control of Covid spreading.

# %% [markdown]
# ***Second pair: Alachua County( Dem) & Lake County (Rep)***

# %%
Flopair02 = Florida[(Florida.get('County Name') == 'Alachua County' ) | (Florida.get('County Name') == 'Lake County' )]
Flopair02
# Out:
#                    County Name  Democrat Votes  Democrat %  Republican Votes  \
# Alachua County  Alachua County           89704          63             50972
# Lake County        Lake County           83505          40            125859
#
#                 Republican %  Population  Population Density (per sq mi)  \
# Alachua County            36      269235                           259.9
# Lake County               60      377516                           263.6
#
#                 Total COVID-19 Cases  \
# Alachua County                 14468
# Lake County                    12966
#
#                                                    Pairing County
# Alachua County  [Charlotte County, Clay County, Hernando Count...
# Lake County                         [Alachua County, Leon County]

# %%
ax = Flopair02.plot.barh(x = 'County Name', y = 'Total COVID-19 Cases', color = ['blue', 'red'], legend = None)
ax.set_xlabel("Total COVID-19 Cases")
# Out:
# Text(0.5, 0, 'Total COVID-19 Cases')

# %%
print('The total COVID-19 Cases differences between Democratic and Republican is', Flopair02.get('Total COVID-19 Cases').iloc[0] - Flopair02.get('Total COVID-19 Cases').iloc[1],'. Therefore, Republican is having a good influence to the control of Covid spreading.')
# Out:
# The total COVID-19 Cases differences between Democratic and Republican is 1502 . Therefore, Republican is having a good influence to the control of Covid spreading.

# %% [markdown]
# ***Third pair: Gadsden County( Dem) & Jackson County (Rep)***

# %%
Flopair03 = Florida[(Florida.get('County Name') == 'Jackson County' ) | (Florida.get('County Name') == 'Gadsden County' )]
Flopair03
# Out:
#                    County Name  Democrat Votes  Democrat %  Republican Votes  \
# Gadsden County  Gadsden County           16153          68              7465
# Jackson County  Jackson County            6766          30             15488
#
#                 Republican %  Population  Population Density (per sq mi)  \
# Gadsden County            31       45393                            88.7
# Jackson County            69       44716                            51.4
#
#                 Total COVID-19 Cases  \
# Gadsden County                  3577
# Jackson County                  4268
#
#                                                    Pairing County
# Gadsden County  [DeSoto County, Jackson County, Okeechobee Cou...
# Jackson County                                                 []

# %%
ax = Flopair03.plot.barh(x = 'County Name', y = 'Total COVID-19 Cases', color = ['blue', 'red'], legend = None)
ax.set_xlabel("Total COVID-19 Cases")
# Out:
# Text(0.5, 0, 'Total COVID-19 Cases')

# %%
print('The total COVID-19 Cases differences between Democratic and Republican is', Flopair03.get('Total COVID-19 Cases').iloc[0] - Flopair03.get('Total COVID-19 Cases').iloc[1],'. Therefore, Republican is having a bad influence to the control of Covid spreading.')
# Out:
# The total COVID-19 Cases differences between Democratic and Republican is -691 . Therefore, Republican is having a bad influence to the control of Covid spreading.

# %% [markdown]
# ***However, we noticed that these selected samples are seemed to be biased towards Republican. Therefore, we will be conducting an A|B test to the dataset.***

# %%
# Getting the Florida mean dem.total cases - mean rep.total cases
FloObservedDifferece = (Florida[Florida.get('Democrat %') > Florida.get('Republican %')].get('Total COVID-19 Cases').mean()) - (Florida[Florida.get('Republican %') > Florida.get('Democrat %')].get('Total COVID-19 Cases').mean())
FloObservedDifferece
# Out:
# 56602.548484848485

# %%
#set up the bootstrap
n_repetitions = 5000
FloDifferences = np.array([])
for i in np.arange(n_repetitions):
    FloShuffled = np.random.permutation(Florida.get('Total COVID-19 Cases'))
    FloShuffledTable = Florida.assign(Shuffled_cases = FloShuffled)
    FloDifferences = np.append(FloDifferences, ((FloShuffledTable[FloShuffledTable.get('Democrat %') > FloShuffledTable.get('Republican %')].get('Shuffled_cases').mean()) - (FloShuffledTable[FloShuffledTable.get('Democrat %') < FloShuffledTable.get('Republican %')].get('Shuffled_cases').mean())))
bpd.DataFrame().assign(Difference = FloDifferences).plot(kind = 'hist', density = True)
plt.scatter(FloObservedDifferece, 0, color ='red', s = 40)

# %% [markdown]
# We can conclude that counties that supports Trump/ Republican ACTUALLY have a higher Total COVID cases.

# %% [markdown]
# ### Blue State: California    (A Blue state is a state where most of the people in the state supports Democratic)

# %%
#Load data for California
California = df_dictionary['California']
California
# Out:
#                        County Name  Democrat Votes  Democrat %  \
# Alameda County      Alameda County          617659          80
# Alpine County        Alpine County             476          64
# Amador County        Amador County            8153          36
# Butte County          Butte County           50426          49
# Calaveras County  Calaveras County           10046          37
# ...                            ...             ...         ...
# Tulare County        Tulare County           66105          45
# Tuolumne County    Tuolumne County           11978          39
# Ventura County      Ventura County          251388          60
# Yolo County            Yolo County           67598          70
# Yuba County            Yuba County           11230          38
#
#                   Republican Votes  Republican %  Population  \
# Alameda County              136309            18     1675900
# Alpine County                  244            33        1169
# Amador County                13585            61       40099
# Butte County                 48730            48      208033
# Calaveras County             16518            61       46112
# ...                            ...           ...         ...
# Tulare County                77579            53      467801
# Tuolumne County              17689            58       54569
# Ventura County              162207            38      843870
# Yolo County                  27292            28      220882
# Yuba County                  17676            59       79779
#
#                   Population Density (per sq mi)  Total COVID-19 Cases  \
# Alameda County                            1898.5                 40262
# Alpine County                                1.6                     5
# Amador County                               61.3                   823
# Butte County                               132.1                  5765
# Calaveras County                            43.3                   677
# ...                                          ...                   ...
# Tulare County                               93.2                 27790
# Tuolumne County                             23.9                  2076
# Ventura County                             378.5                 28643
# Yolo County                                199.5                  6549
# Yuba County                                113.5                  3212
#
#                  Pairing County
# Alameda County               []
# Alpine County                []
# Amador County                []
# Butte County                 []
# Calaveras County             []
# ...                         ...
# Tulare County                []
# Tuolumne County              []
# Ventura County               []
# Yolo County                  []
# Yuba County                  []
#
# [58 rows x 9 columns]

# %% [markdown]
# ***First pair: Sonoma County( Dem) & Placer County (Rep)***

# %%
Calpair01 = California[(California.get('County Name') == 'Sonoma County' ) | (California.get('County Name') == 'Placer County' )]
Calpair01.sort_values(by = 'Democrat %', ascending = False)
Calpair01
# Out:
#                  County Name  Democrat Votes  Democrat %  Republican Votes  \
# Placer County  Placer County          106869          46            122488
# Sonoma County  Sonoma County          199938          75             61825
#
#                Republican %  Population  Population Density (per sq mi)  \
# Placer County            52      404328                           240.6
# Sonoma County            23      490029                           278.2
#
#                Total COVID-19 Cases Pairing County
# Placer County                 10554             []
# Sonoma County                 15702             []

# %%
ax = Calpair01.plot.barh(x = 'County Name', y = 'Total COVID-19 Cases', color = ['red', 'blue'], legend = None)
ax.set_xlabel("Total COVID-19 Cases")
# Out:
# Text(0.5, 0, 'Total COVID-19 Cases')

# %%
print('The total COVID-19 Cases differences between Democratic and Republican is', Calpair01.get('Total COVID-19 Cases').iloc[0] - Calpair01.get('Total COVID-19 Cases').iloc[1],'. Therefore, Republican is having a good influence to the control of Covid spreading.')
# Out:
# The total COVID-19 Cases differences between Democratic and Republican is -5148 . Therefore, Republican is having a good influence to the control of Covid spreading.

# %% [markdown]
# ***Second pair: Fresno County( Dem) & Sutter County (Rep)***

# %%
Calpair02 = California[(California.get('County Name') == 'Fresno County' ) | (California.get('County Name') == 'Sutter County' )]
Calpair02
# Out:
#                  County Name  Democrat Votes  Democrat %  Republican Votes  \
# Fresno County  Fresno County          193025          53            164464
# Sutter County  Sutter County           17367          41             24375
#
#                Republican %  Population  Population Density (per sq mi)  \
# Fresno County            45     1006250                           157.8
# Sutter County            57       97594                           156.2
#
#                Total COVID-19 Cases Pairing County
# Fresno County                 49173             []
# Sutter County                  5369             []

# %%
ax = Calpair02.plot.barh(x = 'County Name', y = 'Total COVID-19 Cases', color = ['blue', 'red'], legend = None)
ax.set_xlabel("Total COVID-19 Cases")
# Out:
# Text(0.5, 0, 'Total COVID-19 Cases')

# %%
print('The total COVID-19 Cases differences between Democratic and Republican is', Calpair02.get('Total COVID-19 Cases').iloc[0] - Calpair02.get('Total COVID-19 Cases').iloc[1],'. Therefore, Republican is having a good influence to the control of Covid spreading.')
# Out:
# The total COVID-19 Cases differences between Democratic and Republican is 43804 . Therefore, Republican is having a good influence to the control of Covid spreading.

# %% [markdown]
# ***Third pair: Santa Barbara County( Dem) & Yuba County(Rep)***

# %%
Calpair03 = California[(California.get('County Name') == 'Santa Barbara County' ) | (California.get('County Name') == 'Yuba County' )]
Calpair03
# Out:
#                                County Name  Democrat Votes  Democrat %  \
# Santa Barbara County  Santa Barbara County          129963          65
# Yuba County                    Yuba County           11230          38
#
#                       Republican Votes  Republican %  Population  \
# Santa Barbara County             65736            33      447218
# Yuba County                      17676            59       79779
#
#                       Population Density (per sq mi)  Total COVID-19 Cases  \
# Santa Barbara County                           113.9                 14190
# Yuba County                                    113.5                  3212
#
#                      Pairing County
# Santa Barbara County             []
# Yuba County                      []

# %%
ax = Calpair03.plot.barh(x = 'County Name', y = 'Total COVID-19 Cases', color = ['blue', 'red'], legend = None)
ax.set_xlabel("Total COVID-19 Cases")
# Out:
# Text(0.5, 0, 'Total COVID-19 Cases')

# %%
frames2 = [Calpair01, Calpair02, Calpair03]
result2 = pd.concat(frames2)
result2
# Out:
#                                County Name  Democrat Votes  Democrat %  \
# Placer County                Placer County          106869          46
# Sonoma County                Sonoma County          199938          75
# Fresno County                Fresno County          193025          53
# Sutter County                Sutter County           17367          41
# Santa Barbara County  Santa Barbara County          129963          65
# Yuba County                    Yuba County           11230          38
#
#                       Republican Votes  Republican %  Population  \
# Placer County                   122488            52      404328
# Sonoma County                    61825            23      490029
# Fresno County                   164464            45     1006250
# Sutter County                    24375            57       97594
# Santa Barbara County             65736            33      447218
# Yuba County                      17676            59       79779
#
#                       Population Density (per sq mi)  Total COVID-19 Cases  \
# Placer County                                  240.6                 10554
# Sonoma County                                  278.2                 15702
# Fresno County                                  157.8                 49173
# Sutter County                                  156.2                  5369
# Santa Barbara County                           113.9                 14190
# Yuba County                                    113.5                  3212
#
#                      Pairing County
# Placer County                    []
# Sonoma County                    []
# Fresno County                    []
# Sutter County                    []
# Santa Barbara County             []
# Yuba County                      []

# %%
print('The total COVID-19 Cases differences between Democratic and Republican is', Calpair03.get('Total COVID-19 Cases').iloc[0] - Calpair03.get('Total COVID-19 Cases').iloc[1],'. Therefore, Republican is having a good influence to the control of Covid spreading.')
# Out:
# The total COVID-19 Cases differences between Democratic and Republican is 10978 . Therefore, Republican is having a good influence to the control of Covid spreading.

# %%
CalObservedDifference= (California[California.get('Democrat %') > California.get('Republican %')].get('Total COVID-19 Cases').mean() )- (California[California.get('Democrat %') < California.get('Republican %')].get('Total COVID-19 Cases').mean())
CalObservedDifference
# Out:
# 40368.086956521736

# %%
CalDifferences = np.array([])
for i in np.arange(n_repetitions):
    CalShuffled= np.random.permutation(California.get('Total COVID-19 Cases'))
    CalShuffledTable = California.assign(Shuffled_cases = CalShuffled)
    CalDifferences = np.append(CalDifferences, ((CalShuffledTable[CalShuffledTable.get('Democrat %') > CalShuffledTable.get('Republican %')].get('Shuffled_cases').mean()) - (CalShuffledTable[CalShuffledTable.get('Democrat %') < CalShuffledTable.get('Republican %')].get('Shuffled_cases').mean())))
bpd.DataFrame().assign(Difference = CalDifferences).plot(kind = 'hist', density = True)
plt.scatter(CalObservedDifference, 0, color ='red', s = 40)

# %% [markdown]
# ### Swing State: Georgia    (A Swing state is a state where people are about uniformly supporting both parties)

# %%
#Load the DataFrame for Georgia
Georgia = df_dictionary['Georgia']
Georgia
# Out:
#                        County Name  Democrat Votes  Democrat %  \
# Appling County      Appling County            1784          21
# Atkinson County    Atkinson County             825          26
# Bacon County          Bacon County             625          13
# Baker County          Baker County             652          42
# Baldwin County      Baldwin County            9140          50
# ...                            ...             ...         ...
# Whitfield County  Whitfield County           10680          29
# Wilcox County        Wilcox County             861          26
# Wilkes County        Wilkes County            2160          43
# Wilkinson County  Wilkinson County            2074          44
# Worth County          Worth County            2395          26
#
#                   Republican Votes  Republican %  Population  \
# Appling County                6570            78       18246
# Atkinson County               2300            73        8068
# Bacon County                  4017            86       11196
# Baker County                   897            58        2990
# Baldwin County                8903            49       44887
# ...                            ...           ...         ...
# Whitfield County             25644            70      105007
# Wilcox County                 2402            73        8443
# Wilkes County                 2823            56        9690
# Wilkinson County              2665            56        8865
# Worth County                  6830            74       20192
#
#                   Population Density (per sq mi)  Total COVID-19 Cases  \
# Appling County                              36.0                  1322
# Atkinson County                             24.1                   568
# Bacon County                                39.2                   706
# Baker County                                 9.6                   116
# Baldwin County                             171.5                  2691
# ...                                          ...                   ...
# Whitfield County                           354.3                  9424
# Wilcox County                               23.7                   329
# Wilkes County                               21.4                   410
# Wilkinson County                            20.9                   466
# Worth County                                37.2                   747
#
#                                   Pairing County
# Appling County                                []
# Atkinson County                 [Hancock County]
# Bacon County      [Hancock County, Macon County]
# Baker County                                  []
# Baldwin County                                []
# ...                                          ...
# Whitfield County              [Dougherty County]
# Wilcox County                   [Hancock County]
# Wilkes County                                 []
# Wilkinson County                              []
# Worth County                                  []
#
# [159 rows x 9 columns]

# %% [markdown]
# ***First pair: Barrow County( Dem) & Chatham County(Rep)***

# %%
Geopair01 = Georgia[(Georgia.get('County Name') == 'Chatham County' ) | (Georgia.get('County Name') == 'Barrow County' )]
Geopair01.sort_values(by = 'Democrat %')
# Out:
#                    County Name  Democrat Votes  Democrat %  Republican Votes  \
# Barrow County    Barrow County           10453          28             26804
# Chatham County  Chatham County           78247          59             53232
#
#                 Republican %  Population  Population Density (per sq mi)  \
# Barrow County             71       85646                           435.0
# Chatham County            40      289694                           435.4
#
#                 Total COVID-19 Cases                       Pairing County
# Barrow County                   4006  [Dougherty County, Rockdale County]
# Chatham County                 11718                                   []

# %%
ax = Geopair01.plot.barh(x = 'County Name', y = 'Total COVID-19 Cases', color = ['red', 'blue'], legend = None)
ax.set_xlabel("Total COVID-19 Cases")
# Out:
# Text(0.5, 0, 'Total COVID-19 Cases')

# %%
print('The total COVID-19 Cases differences between Democratic and Republican is', Geopair01.get('Total COVID-19 Cases').iloc[0] - Geopair01.get('Total COVID-19 Cases').iloc[1],'. Therefore, Republican is having a bad influence to the control of Covid spreading.')
# Out:
# The total COVID-19 Cases differences between Democratic and Republican is -7712 . Therefore, Republican is having a bad influence to the control of Covid spreading.

# %% [markdown]
# ***Second pair: Newton County( Dem) & Whitfield County(Rep)***

# %%
Geopair02 = Georgia[(Georgia.get('County Name') == 'Newton County' ) | (Georgia.get('County Name') == 'Whitfield County' )]
Geopair02
# Out:
#                        County Name  Democrat Votes  Democrat %  \
# Newton County        Newton County           29789          55
# Whitfield County  Whitfield County           10680          29
#
#                   Republican Votes  Republican %  Population  \
# Newton County                23869            44      114067
# Whitfield County             25644            70      105007
#
#                   Population Density (per sq mi)  Total COVID-19 Cases  \
# Newton County                              363.6                  4044
# Whitfield County                           354.3                  9424
#
#                       Pairing County
# Newton County                     []
# Whitfield County  [Dougherty County]

# %%
ax = Geopair02.plot.barh(x = 'County Name', y = 'Total COVID-19 Cases', color = ['blue', 'red'], legend = None)
ax.set_xlabel("Total COVID-19 Cases")
# Out:
# Text(0.5, 0, 'Total COVID-19 Cases')

# %%
print('The total COVID-19 Cases differences between Democratic and Republican is', Geopair02.get('Total COVID-19 Cases').iloc[0] - Geopair02.get('Total COVID-19 Cases').iloc[1],'. Therefore, Republican is having a bad influence to the control of Covid spreading.')
# Out:
# The total COVID-19 Cases differences between Democratic and Republican is -5380 . Therefore, Republican is having a bad influence to the control of Covid spreading.

# %% [markdown]
# ***Third pair: Liberty County( Dem) & Lumpkin County(Rep)***

# %%
Geopair03 = Georgia[(Georgia.get('County Name') == 'Liberty County' ) | (Georgia.get('County Name') == 'Lumpkin County' )]
Geopair03
# Out:
#                    County Name  Democrat Votes  Democrat %  Republican Votes  \
# Liberty County  Liberty County           13104          61              7959
# Lumpkin County  Lumpkin County            3126          20             12163
#
#                 Republican %  Population  Population Density (per sq mi)  \
# Liberty County            37       62264                           107.0
# Lumpkin County            78       34321                           108.1
#
#                 Total COVID-19 Cases  \
# Liberty County                  1648
# Lumpkin County                  1575
#
#                                                    Pairing County
# Liberty County  [Camden County, Colquitt County, Effingham Cou...
# Lumpkin County                                                 []

# %%
ax = Geopair03.plot.barh(x = 'County Name', y = 'Total COVID-19 Cases', color = ['blue', 'red'], legend = None)
ax.set_xlabel("Total COVID-19 Cases")
# Out:
# Text(0.5, 0, 'Total COVID-19 Cases')

# %%
print('The total COVID-19 Cases differences between Democratic and Republican is', Geopair03.get('Total COVID-19 Cases').iloc[0] - Geopair03.get('Total COVID-19 Cases').iloc[1],'. Therefore, Republican is having a good influence to the control of Covid spreading.')
# Out:
# The total COVID-19 Cases differences between Democratic and Republican is 73 . Therefore, Republican is having a good influence to the control of Covid spreading.

# %%
GeoObservedDifference= (Georgia[Georgia.get('Democrat %') > Georgia.get('Republican %')].get('Total COVID-19 Cases').mean() )- (Georgia[Georgia.get('Democrat %') < Georgia.get('Republican %')].get('Total COVID-19 Cases').mean())
GeoObservedDifference
# Out:
# 6455.783720930233

# %%
GeoDifferences = np.array([])
for i in np.arange(n_repetitions):
    GeoShuffled= np.random.permutation(Georgia.get('Total COVID-19 Cases'))
    GeoShuffledTable = Georgia.assign(Shuffled_cases = GeoShuffled)
    GeoDifferences = np.append(GeoDifferences, ((GeoShuffledTable[GeoShuffledTable.get('Democrat %') > GeoShuffledTable.get('Republican %')].get('Shuffled_cases').mean()) - (GeoShuffledTable[GeoShuffledTable.get('Democrat %') < GeoShuffledTable.get('Republican %')].get('Shuffled_cases').mean())))
bpd.DataFrame().assign(Difference = GeoDifferences).plot(kind = 'hist', density = True)
plt.scatter(GeoObservedDifference, 0, color ='red', s = 40)

# %% [markdown]
# # Export DataFrames as CSV files for analysis

# %%
#for state in state_list:
#    if state == 'Alaska':
#        continue
#    df_dictionary[state].to_csv(state + '_csv')
